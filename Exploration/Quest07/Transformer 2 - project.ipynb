# %% [markdown]
# # 한국어 데이터로 챗봇 만들기
# 프로젝트 제출 루브릭
# | **학습 목표** | **평가 기준** |
# |----------------|----------------|
# | 한국어 전처리를 통해 학습 데이터셋을 구축하였다. | 공백과 특수문자 처리, 토크나이징, 병렬데이터 구축의 과정이 적절히 진행되었다. |
# | 트랜스포머 모델을 구현하여 한국어 챗봇 모델 학습을 정상적으로 진행하였다. | 구현한 트랜스포머 모델이 한국어 병렬 데이터 학습 시 안정적으로 수렴하였다. |
# | 한국어 입력문장에 대해 한국어로 답변하는 함수를 구현하였다. | 한국어 입력문장에 맥락에 맞는 한국어로 답변을 리턴하였다. |

# %% [markdown]
# # Step 0. Library

# %%
# !pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.12/site-packages (0.2.1)

# %%
import pandas as pd
import sentencepiece as spm
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
import math
import time
import re
import os

# %% [markdown]
# # Step 1. 데이터 수집하기

# %%
#!wget https://github.com/songys/Chatbot_data/raw/master/ChatbotData.csv
#!mv ChatbotData.csv data/chatbot

# %% [markdown]
# 데이터 자체가 이런식으로 표현되어 있다.
#
# | **Q** | **A** | **Label** |
# |----------------|----------------|----------------|
# |12시 땡!, |하루가 또 가네요., |0|
#
# ---
#
# 데이터의 Label은 일상다반사 0, 이별(부정) 1, 사랑(긍정) 2로 레이블링로 되어있다.
#
# ---

# %% [markdown]
# # Step 2. 데이터 전처리하기

# %%
url = 'https://raw.githubusercontent.com/songys/Chatbot_data/master/ChatbotData.csv'
df = pd.read_csv(url)

# %%
def  preprocess_sentence(sentence):
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = sentence.strip()
    
    return sentence

questions = [preprocess_sentence(q) for q in df['Q']]
answers   = [preprocess_sentence(a) for a in df['A']]

# %% [markdown]
# # Step 3. SentencePiece 사용하기

# %%
corpus = questions + answers
print('전체 샘플 수 :', len(corpus)/2)
with open('data/chatbot/corpus.txt', 'w', encoding='utf-8') as f:
    for s in corpus:
        f.write(s + '\n')
# Out:
# 전체 샘플 수 : 11823.0

# %%
spm.SentencePieceTrainer.Train(
    input='data/chatbot/corpus.txt',
    model_prefix='data/chatbot/chatbot_tokenizer',
    vocab_size=6000, # size 2000 4000 6000 8000 성능 차이가 안보임
    model_type='unigram',
    character_coverage=0.9995,
    pad_id=0, unk_id=1, bos_id=2, eos_id=3
)

sp = spm.SentencePieceProcessor(model_file='data/chatbot/chatbot_tokenizer.model')
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/chatbot/corpus.txt
#   input_format:
#   model_prefix: data/chatbot/chatbot_tokenizer
#   model_type: UNIGRAM
#   vocab_size: 6000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 1
#   bos_id: 2
#   eos_id: 3
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: data/chatbot/corpus.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 23646 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=369707
# trainer_interface.cc(552) LOG(INFO) Done: 99.9502% characters are covered.
# trainer_interface.cc(562) LOG(INFO) Alphabet size=1081
# trainer_interface.cc(563) LOG(INFO) Final character coverage=0.999502
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 23646 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=171267
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 18348 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 23646
# trainer_interface.cc(611) LOG(INFO) Done! 20693
# unigram_model_trainer.cc(602) LOG(INFO) Using 20693 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=10788 obj=11.1226 num_tokens=40638 num_tokens/piece=3.76696
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=9359 obj=10.2784 num_tokens=40743 num_tokens/piece=4.35335
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=7019 obj=10.5779 num_tokens=43723 num_tokens/piece=6.22923
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=7019 obj=10.5243 num_tokens=43759 num_tokens/piece=6.23436
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=6600 obj=10.7084 num_tokens=44632 num_tokens/piece=6.76242
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=6600 obj=10.6943 num_tokens=44639 num_tokens/piece=6.76348
# trainer_interface.cc(689) LOG(INFO) Saving model: data/chatbot/chatbot_tokenizer.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: data/chatbot/chatbot_tokenizer.vocab

# %%
# 토크나이징 + BOS/EOS
tokenized_questions = [sp.encode_as_ids(q) for q in questions]
tokenized_answers   = [[sp.bos_id()] + sp.encode_as_ids(a) + [sp.eos_id()] for a in answers]

# %%
def sequence_len(data):
    import numpy as np
    """
    문장길이의 평균값, 최대값, 표준편차를 계산해 본다.
    """
    num_tokens = [len(tokens) for tokens in data]
    num_tokens = np.array(num_tokens)

    sequence_mean = np.mean(num_tokens)
    sequence_max = np.max(num_tokens)
    sequence_std = np.std(num_tokens)
    
    print('문장길이 평균 : ', sequence_mean)
    print('문장길이 최대 : ', sequence_max)
    print('문장길이 표준편차 : ', sequence_std)

    max_tokens = sequence_mean + 2 * sequence_std
    maxlen = int(max_tokens)
    print(f'적정 문장 길이 : {maxlen}')
    print(f'전체 문장의 {np.sum([len(tokens) for tokens in data] < max_tokens) / len(num_tokens):.2f}%가 maxlen 설정값 이내에 포함됩니다. ')
    return sequence_mean, sequence_max, sequence_std, maxlen

print("Q")
sequence_len(tokenized_questions)
print("\nA")
sequence_len(tokenized_answers)
# Out:
# Q
# 문장길이 평균 :  5.945699061151992
# 문장길이 최대 :  24
# 문장길이 표준편차 :  2.7859609074600438
# 적정 문장 길이 : 11
# 전체 문장의 0.96%가 maxlen 설정값 이내에 포함됩니다.
#
# A
# 문장길이 평균 :  9.181510614903155
# 문장길이 최대 :  38
# 문장길이 표준편차 :  3.0336364369070785
# 적정 문장 길이 : 15
# 전체 문장의 0.96%가 maxlen 설정값 이내에 포함됩니다.
# (np.float64(9.181510614903155),
#  np.int64(38),
#  np.float64(3.0336364369070785),
#  15)

# %%
def truncate(seq, max_len):
    return seq[:max_len]

MAX_LEN = 100   # 그냥 높게 잡음
                # sequence_len함수에 따라, 적정문장 길이 기준으로 진행을 해도 성능 차이가 없음

tokenized_questions = [truncate(sp.encode_as_ids(q), MAX_LEN) for q in questions]
tokenized_answers   = [truncate([sp.bos_id()] + sp.encode_as_ids(a) + [sp.eos_id()], MAX_LEN) for a in answers]

print(f"Using MAX_LEN = {MAX_LEN} (all sequences truncated to this length)")
# Out:
# Using MAX_LEN = 100 (all sequences truncated to this length)

# %% [markdown]
# # Step 4. 모델 구성하기

# %% [markdown]
# ## Step 4-1. Model class 선언
# - node 학습시 코드와 거의 유사
# - 주석은 더 자세히 알기위해 LLM 거치고 봄

# %%
class PositionalEncoding(nn.Module):
    """
    입력 시퀀스에 위치 정보를 인코딩(Positional Encoding)으로 더해주는 모듈.
    트랜스포머(Transformer) 모델에서 단어의 순서를 반영하기 위해 사용됨.

    Args:
        position (int): 입력 시퀀스의 최대 길이 (예: 1000)
        d_model (int): 임베딩 벡터의 차원 수 (모델 차원, 예: 512)

    Attributes:
        pos_encoding (torch.Tensor): [1, position, d_model] 형태의 위치 인코딩 텐서
    """

    def __init__(self, position, d_model):
        super().__init__()
        # 사인/코사인 함수를 이용해 위치 인코딩 행렬 생성
        self.pos_encoding = self._build_pos_encoding(position, d_model)

    def _get_angles(self, pos, i, d_model):
        """
        각 위치(pos)와 차원(i)에 대한 angle 값을 계산.

        angle = pos / (10000^(2*(i//2)/d_model))

        Args:
            pos (torch.Tensor): [position, 1] 형태의 위치 벡터
            i (torch.Tensor): [1, d_model] 형태의 차원 인덱스 벡터
            d_model (int): 모델 차원 수

        Returns:
            torch.Tensor: 각 (pos, i)에 대응하는 angle 값
        """
        return pos / (10000 ** ((2 * (i // 2)) / d_model))

    def _build_pos_encoding(self, position, d_model):
        """
        위치 인코딩(Positional Encoding) 행렬을 생성하는 함수.

        각 위치와 차원에 대해 sin, cos 값을 교차로 적용하여
        단어의 순서를 모델이 학습할 수 있도록 함.

        Args:
            position (int): 시퀀스의 최대 길이
            d_model (int): 임베딩 차원 수

        Returns:
            torch.Tensor: [1, position, d_model] 형태의 위치 인코딩 텐서
        """
        # 각 위치와 차원에 대응하는 angle 값 계산
        angle_rads = self._get_angles(
            torch.arange(position, dtype=torch.float32).unsqueeze(1),  # [position, 1]
            torch.arange(d_model, dtype=torch.float32).unsqueeze(0),  # [1, d_model]
            d_model
        )

        # 짝수 인덱스(0, 2, 4, ...)에는 sin, 홀수 인덱스(1, 3, 5, ...)에는 cos 적용
        sines = torch.sin(angle_rads[:, 0::2])
        cosines = torch.cos(angle_rads[:, 1::2])

        # sin과 cos을 번갈아 채워 넣은 위치 인코딩 행렬 구성
        pos_encoding = torch.zeros(position, d_model)
        pos_encoding[:, 0::2] = sines
        pos_encoding[:, 1::2] = cosines

        # 배치 차원(1)을 추가하여 [1, position, d_model] 형태로 반환
        return pos_encoding.unsqueeze(0)

    def forward(self, x):
        """
        입력 임베딩 텐서에 위치 인코딩을 더하는 함수.

        Args:
            x (torch.Tensor): 입력 임베딩 텐서 [batch_size, seq_len, d_model]

        Returns:
            torch.Tensor: 위치 인코딩이 더해진 텐서 [batch_size, seq_len, d_model]
        """
        # 입력 시퀀스 길이에 맞춰 위치 인코딩을 잘라내고, 입력 텐서에 더함
        return x + self.pos_encoding[:, :x.size(1), :].to(x.device)

# %%
def scaled_dot_product_attention(query, key, value, mask=None):
    """
    Scaled Dot-Product Attention 계산 함수.

    트랜스포머(Transformer) 구조에서 Query, Key, Value 벡터 간의 유사도를 계산하고,
    그 유사도(Attention Score)를 바탕으로 Value의 가중합을 구함.

    수식:
        Attention(Q, K, V) = softmax( (QK^T) / sqrt(d_k) ) V

    Args:
        query (torch.Tensor): Query 텐서 [batch_size, num_heads, seq_len_q, depth]
        key (torch.Tensor): Key 텐서 [batch_size, num_heads, seq_len_k, depth]
        value (torch.Tensor): Value 텐서 [batch_size, num_heads, seq_len_v, depth_v]
        mask (torch.Tensor, optional): 마스크 텐서 (padding 또는 look-ahead mask). 
                                       0인 위치는 무시됨. 기본값 None.

    Returns:
        tuple[torch.Tensor, torch.Tensor]:
            - output: Attention이 적용된 결과 [batch_size, num_heads, seq_len_q, depth_v]
            - attention_weights: Attention 가중치 행렬 [batch_size, num_heads, seq_len_q, seq_len_k]
    """

    # (1) Query와 Key의 내적 계산 → [batch_size, num_heads, seq_len_q, seq_len_k]
    matmul_qk = torch.matmul(query, key.transpose(-1, -2))

    # (2) 차원 수로 나누어 스케일 조정 (값이 너무 커지는 것을 방지)
    depth = key.size(-1)
    logits = matmul_qk / math.sqrt(depth)

    # (3) 마스크(mask)가 주어지면, 해당 위치는 매우 작은 값(-1e9)으로 채워 softmax 영향 제거
    if mask is not None:
        logits = logits.masked_fill(mask == 0, -1e9)

    # (4) 각 Query에 대해 Key와의 유사도 확률 분포 계산 (softmax)
    attention_weights = F.softmax(logits, dim=-1)

    # (5) Attention 가중치로 Value를 가중합 → 문맥(Context) 벡터 생성
    output = torch.matmul(attention_weights, value)

    return output, attention_weights

# %%
class MultiHeadAttention(nn.Module):
    """
    멀티헤드 어텐션(Multi-Head Attention) 모듈.

    트랜스포머의 핵심 구성요소로, 입력 벡터를 여러 개의 '헤드(head)'로 분할하여
    병렬적으로 어텐션을 수행함으로써 서로 다른 의미 공간에서의 관계를 학습하도록 함.

    수식:
        MultiHead(Q, K, V) = Concat(head_1, ..., head_h) W^O
        where head_i = Attention(QW_i^Q, KW_i^K, VW_i^V)

    Args:
        d_model (int): 입력 임베딩 차원 수 (예: 512)
        num_heads (int): 어텐션 헤드의 개수 (예: 8)

    Attributes:
        depth (int): 각 헤드의 임베딩 차원 (d_model / num_heads)
        query_dense (nn.Linear): Query 변환용 선형 레이어
        key_dense (nn.Linear): Key 변환용 선형 레이어
        value_dense (nn.Linear): Value 변환용 선형 레이어
        out_dense (nn.Linear): 여러 헤드의 출력을 다시 합쳐주는 출력 레이어
    """

    def __init__(self, d_model, num_heads):
        super().__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        # (1) d_model이 num_heads로 나누어 떨어져야 함 (각 헤드의 차원이 동일해야 하므로)
        assert d_model % num_heads == 0, "d_model은 num_heads로 나누어 떨어져야 합니다."

        # (2) 각 헤드별 차원 (depth)
        self.depth = d_model // num_heads

        # (3) Query, Key, Value를 위한 선형 변환 레이어 정의
        self.query_dense = nn.Linear(d_model, d_model)
        self.key_dense   = nn.Linear(d_model, d_model)
        self.value_dense = nn.Linear(d_model, d_model)

        # (4) 여러 헤드의 출력을 결합한 후 최종 선형 변환
        self.out_dense   = nn.Linear(d_model, d_model)

    def split_heads(self, x, batch_size):
        """
        입력 텐서를 여러 개의 헤드로 분리하는 함수.

        입력 형태: [batch_size, seq_len, d_model]
        출력 형태: [batch_size, num_heads, seq_len, depth]

        Args:
            x (torch.Tensor): 입력 텐서
            batch_size (int): 배치 크기

        Returns:
            torch.Tensor: 헤드 분할 및 차원 변환된 텐서
        """
        # [batch_size, seq_len, d_model] → [batch_size, seq_len, num_heads, depth]
        x = x.view(batch_size, -1, self.num_heads, self.depth)

        # 어텐션 계산을 위해 차원 순서를 변경
        # [batch_size, num_heads, seq_len, depth]
        return x.permute(0, 2, 1, 3)

    def forward(self, query, key, value, mask=None):
        """
        멀티헤드 어텐션 연산을 수행하는 함수.

        Args:
            query (torch.Tensor): Query 입력 [batch_size, seq_len_q, d_model]
            key (torch.Tensor): Key 입력 [batch_size, seq_len_k, d_model]
            value (torch.Tensor): Value 입력 [batch_size, seq_len_v, d_model]
            mask (torch.Tensor, optional): 어텐션 마스크 (padding 또는 look-ahead). 기본값 None.

        Returns:
            torch.Tensor: 어텐션이 적용된 출력 [batch_size, seq_len_q, d_model]
        """
        batch_size = query.size(0)

        # (1) 입력 벡터를 각각 선형 변환 후, 여러 헤드로 분리
        query = self.split_heads(self.query_dense(query), batch_size)
        key   = self.split_heads(self.key_dense(key), batch_size)
        value = self.split_heads(self.value_dense(value), batch_size)

        # (2) 스케일 조정된 닷프로덕트 어텐션 수행 (각 헤드별로 병렬 계산)
        scaled_attention, _ = scaled_dot_product_attention(query, key, value, mask)

        # (3) 어텐션 결과를 원래 차원 순서로 되돌림
        # [batch_size, num_heads, seq_len_q, depth] → [batch_size, seq_len_q, num_heads, depth]
        scaled_attention = scaled_attention.permute(0, 2, 1, 3).contiguous()

        # (4) 모든 헤드를 하나로 결합 (concat)
        concat_attention = scaled_attention.view(batch_size, -1, self.d_model)

        # (5) 최종 선형 변환을 통해 출력 생성
        output = self.out_dense(concat_attention)

        return output

# %%
def create_padding_mask(x, pad_id=0):
    """
    입력 시퀀스 내 패딩 토큰을 감지하여 마스크를 생성하는 함수.

    트랜스포머에서 **패딩 토큰(PAD)** 은 실제 의미가 없으므로,  
    Attention 계산 시 이 위치의 값이 다른 토큰의 연산에 영향을 주지 않도록  
    마스크(mask)를 만들어줌.

    Args:
        x (torch.Tensor): 입력 시퀀스 텐서 [batch_size, seq_len]
        pad_id (int, optional): 패딩 토큰의 ID 값 (기본값: 0)

    Returns:
        torch.Tensor: 패딩 마스크 텐서 [batch_size, 1, 1, seq_len]
                      (1: 유효 토큰, 0: 패딩 위치)
    """
    # pad_id가 아닌 위치는 1(True), pad_id인 위치는 0(False)
    mask = (x != pad_id).unsqueeze(1).unsqueeze(2).float()
    # shape: [batch_size, 1, 1, seq_len]
    return mask


def create_look_ahead_mask(seq_len):
    """
    디코더(Decoder)에서 미래 토큰을 보지 못하도록 하는 마스크 생성 함수.

    트랜스포머의 디코더는 **오토리그레시브(Autoregressive)** 하게 동작해야 하므로,  
    현재 시점 이후의 단어(토큰)를 참고하지 않도록 상삼각 부분을 0으로 채움.

    Args:
        seq_len (int): 시퀀스 길이 (입력 문장의 토큰 개수)

    Returns:
        torch.Tensor: Look-ahead 마스크 [seq_len, seq_len]
                      (하삼각 1, 상삼각 0)
    """
    # torch.tril() → 하삼각(lower triangular) 행렬을 1로 채움
    mask = torch.tril(torch.ones(seq_len, seq_len))
    # shape: [seq_len, seq_len]
    return mask

# %%
class EncoderLayer(nn.Module):
    """
    트랜스포머 인코더의 기본 단위 레이어 (Encoder Layer).

    한 층의 인코더는 다음 세 단계로 구성됨:
        1) 멀티헤드 어텐션 (Multi-Head Attention)
        2) 잔차 연결 + 레이어 정규화 (Residual Connection + LayerNorm)
        3) 피드포워드 네트워크 (Position-wise Feed-Forward Network)

    수식:
        Out1 = LayerNorm(x + Dropout(MHA(x, x, x)))
        Out2 = LayerNorm(Out1 + Dropout(FFN(Out1)))

    Args:
        d_model (int): 입력 임베딩 차원 (예: 512)
        num_heads (int): 멀티헤드 어텐션의 헤드 개수 (예: 8)
        ff_dim (int): 피드포워드 네트워크 내부 차원 (예: 2048)
        dropout (float, optional): 드롭아웃 비율 (기본값: 0.1)
    """

    def __init__(self, d_model, num_heads, ff_dim, dropout=0.1):
        super().__init__()

        # (1) 멀티헤드 어텐션 블록
        self.mha = MultiHeadAttention(d_model, num_heads)

        # (2) 포지션별 피드포워드 네트워크
        self.ffn = nn.Sequential(
            nn.Linear(d_model, ff_dim),
            nn.ReLU(),
            nn.Linear(ff_dim, d_model)
        )

        # (3) 잔차 연결 후 정규화
        self.norm1 = nn.LayerNorm(d_model, eps=1e-6)
        self.norm2 = nn.LayerNorm(d_model, eps=1e-6)

        # (4) 드롭아웃
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

    def forward(self, x, mask):
        """
        인코더 한 층의 순전파(forward) 연산 수행.

        Args:
            x (torch.Tensor): 입력 텐서 [batch_size, seq_len, d_model]
            mask (torch.Tensor): 패딩 마스크 [batch_size, 1, 1, seq_len]

        Returns:
            torch.Tensor: 인코더 레이어의 출력 [batch_size, seq_len, d_model]
        """
        # (1) 멀티헤드 어텐션 수행
        attn_out = self.mha(x, x, x, mask)
        attn_out = self.dropout1(attn_out)

        # (2) 잔차 연결 및 정규화
        out1 = self.norm1(x + attn_out)

        # (3) 피드포워드 네트워크 적용
        ffn_out = self.ffn(out1)
        ffn_out = self.dropout2(ffn_out)

        # (4) 잔차 연결 및 정규화
        out2 = self.norm2(out1 + ffn_out)

        return out2


class Encoder(nn.Module):
    """
    트랜스포머 인코더 전체 구조 (N개의 Encoder Layer로 구성됨).

    전체 인코더는 다음 단계를 거침:
        1) 임베딩 + 위치 인코딩(Positional Encoding)
        2) 드롭아웃
        3) N개의 EncoderLayer 반복 적용

    Args:
        vocab_size (int): 단어 사전 크기
        num_layers (int): 인코더 레이어 수 (예: 6)
        ff_dim (int): 피드포워드 내부 차원 (예: 2048)
        d_model (int): 임베딩 차원 (예: 512)
        num_heads (int): 어텐션 헤드 수 (예: 8)
        max_len (int, optional): 최대 시퀀스 길이 (기본값: 40)
        dropout (float, optional): 드롭아웃 비율 (기본값: 0.1)
    """

    def __init__(self, vocab_size, num_layers, ff_dim, d_model, num_heads, max_len=40, dropout=0.1):
        super().__init__()

        self.d_model = d_model

        # (1) 단어 임베딩 레이어 (PAD 토큰은 0으로 설정)
        self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=0)

        # (2) 위치 인코딩(Positional Encoding)
        self.pos_encoding = PositionalEncoding(max_len, d_model)

        # (3) 드롭아웃 레이어
        self.dropout = nn.Dropout(dropout)

        # (4) N개의 인코더 레이어를 리스트로 구성
        self.enc_layers = nn.ModuleList([
            EncoderLayer(d_model, num_heads, ff_dim, dropout)
            for _ in range(num_layers)
        ])

    def forward(self, x, mask):
        """
        인코더 전체의 순전파(forward) 연산 수행.

        Args:
            x (torch.Tensor): 입력 시퀀스 [batch_size, seq_len]
            mask (torch.Tensor): 패딩 마스크 [batch_size, 1, 1, seq_len]

        Returns:
            torch.Tensor: 인코더 출력 [batch_size, seq_len, d_model]
        """
        # (1) 임베딩 후 스케일 조정 (√d_model)
        x = self.embedding(x) * math.sqrt(self.d_model)

        # (2) 위치 인코딩 추가
        x = self.pos_encoding(x)

        # (3) 드롭아웃 적용
        x = self.dropout(x)

        # (4) 각 인코더 레이어를 순차적으로 통과
        for layer in self.enc_layers:
            x = layer(x, mask)

        return x

# %%
# ==============================================
# 디코더의 기본 구성 단위 (DecoderLayer)
# ==============================================
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, ff_dim, dropout=0.1):
        super().__init__()

        # (1) 첫 번째: 디코더의 Self-Attention (미래 토큰 가리기)
        self.self_mha = MultiHeadAttention(d_model, num_heads)

        # (2) 두 번째: 인코더-디코더 어텐션 (인코더 출력과 결합)
        self.encdec_mha = MultiHeadAttention(d_model, num_heads)

        # (3) 세 번째: Position-wise Feed Forward Network
        self.ffn = nn.Sequential(
            nn.Linear(d_model, ff_dim),
            nn.ReLU(),
            nn.Linear(ff_dim, d_model)
        )

        # (4) 각 블록 뒤의 Layer Normalization
        self.norm1 = nn.LayerNorm(d_model, eps=1e-6)
        self.norm2 = nn.LayerNorm(d_model, eps=1e-6)
        self.norm3 = nn.LayerNorm(d_model, eps=1e-6)

        # (5) Dropout (과적합 방지용)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)
        self.dropout3 = nn.Dropout(dropout)

    def forward(self, x, enc_output, look_ahead_mask, padding_mask):
        """
        x: 디코더 입력 (target embedding)
        enc_output: 인코더 출력 (context)
        look_ahead_mask: 미래 단어 마스킹
        padding_mask: 인코더 패딩 마스크
        """

        # -------------------------------
        # (1) Masked Self-Attention
        #    - 자기 자신 문장에서 미래 단어를 보지 않도록 마스크 적용
        # -------------------------------
        self_attn = self.self_mha(x, x, x, look_ahead_mask)
        self_attn = self.dropout1(self_attn)
        out1 = self.norm1(x + self_attn)  # 잔차연결 + 정규화

        # -------------------------------
        # (2) Encoder-Decoder Attention
        #    - 인코더 출력(enc_output)을 Query로 활용
        #    - 디코더가 인코더 정보에 집중할 수 있게 함
        # -------------------------------
        encdec_attn = self.encdec_mha(out1, enc_output, enc_output, padding_mask)
        encdec_attn = self.dropout2(encdec_attn)
        out2 = self.norm2(out1 + encdec_attn)  # 잔차연결 + 정규화

        # -------------------------------
        # (3) Feed Forward Network
        #    - 각 위치별 독립적 비선형 변환
        # -------------------------------
        ffn_out = self.ffn(out2)
        ffn_out = self.dropout3(ffn_out)
        out3 = self.norm3(out2 + ffn_out)  # 잔차연결 + 정규화

        return out3


# ==============================================
# 디코더 전체 (여러 DecoderLayer 쌓은 형태)
# ==============================================
class Decoder(nn.Module):
    def __init__(self, vocab_size, num_layers, ff_dim, d_model, num_heads, max_len=200, dropout=0.1):
        super().__init__()

        self.d_model = d_model

        # (1) 단어 임베딩 레이어
        #   - 토큰 인덱스를 d_model 차원의 벡터로 변환
        self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=0)

        # (2) 위치 인코딩 (PositionalEncoding)
        #   - 문장 내 단어의 순서 정보를 벡터에 추가
        self.pos_encoding = PositionalEncoding(max_len, d_model)

        # (3) Dropout
        self.dropout = nn.Dropout(dropout)

        # (4) 디코더 층 여러 개 쌓기
        self.dec_layers = nn.ModuleList([
            DecoderLayer(d_model, num_heads, ff_dim, dropout)
            for _ in range(num_layers)
        ])

    def forward(self, x, enc_output, look_ahead_mask, padding_mask):
        """
        x: 디코더 입력 (target 문장, [batch_size, tgt_seq_len])
        enc_output: 인코더 출력 (context)
        look_ahead_mask: 디코더용 마스크 (미래 단어 가리기)
        padding_mask: 인코더 입력의 패딩 위치 마스크
        """

        # (1) 임베딩 + √d_model 스케일링 (논문 방식)
        x = self.embedding(x) * math.sqrt(self.d_model)

        # (2) 위치 인코딩 추가
        x = self.pos_encoding(x)

        # (3) 드롭아웃 적용
        x = self.dropout(x)

        # (4) 여러 개의 디코더 레이어를 순차적으로 통과
        for layer in self.dec_layers:
            x = layer(x, enc_output, look_ahead_mask, padding_mask)

        # (5) 최종 디코더 출력 반환
        return x

# %%
# ==============================================
# 전체 Transformer 모델 클래스
#  - Encoder + Decoder + Final Linear Projection
# ==============================================
class Transformer(nn.Module):
    def __init__(
        self,
        vocab_size,        # 단어 집합 크기 (어휘 수)
        num_layers=6,      # 인코더/디코더 층 수
        units=2048,        # FFN 내부 차원 (hidden dimension)
        d_model=512,       # 임베딩 및 모델 차원
        num_heads=8,       # 멀티헤드 어텐션의 헤드 개수
        dropout=0.1,       # 드롭아웃 비율
        max_len=200        # 입력 시퀀스의 최대 길이
    ):
        super().__init__()

        # -------------------------------
        # (1) 인코더 (Encoder)
        # -------------------------------
        # 입력 문장을 인코딩하여 문맥(context) 표현을 생성
        self.encoder = Encoder(
            vocab_size=vocab_size,
            num_layers=num_layers,
            ff_dim=units,
            d_model=d_model,
            num_heads=num_heads,
            max_len=max_len,
            dropout=dropout
        )

        # -------------------------------
        # (2) 디코더 (Decoder)
        # -------------------------------
        # 이전 단어들을 바탕으로 다음 단어를 예측
        self.decoder = Decoder(
            vocab_size=vocab_size,
            num_layers=num_layers,
            ff_dim=units,
            d_model=d_model,
            num_heads=num_heads,
            max_len=max_len,
            dropout=dropout
        )

        # -------------------------------
        # (3) 출력 변환층 (Final Linear Layer)
        # -------------------------------
        # 디코더 출력을 어휘 크기(vocab_size)로 투영하여
        # 각 단어의 예측 확률 분포를 구함
        self.final_linear = nn.Linear(d_model, vocab_size)


    def forward(self, inputs, dec_inputs):
        """
        inputs:      인코더 입력 (source sentence)
        dec_inputs:  디코더 입력 (target sentence shifted right)
        """

        # ======================================================
        # (1) 마스크 생성 단계
        # ======================================================

        # 인코더 입력의 패딩 토큰을 무시하기 위한 마스크
        enc_padding_mask = create_padding_mask(inputs, sp.pad_id())

        # 디코더용 look-ahead 마스크 (미래 단어 가리기)
        #   - seq_len 크기의 하삼각 행렬 생성 (torch.tril)
        look_ahead_mask = create_look_ahead_mask(dec_inputs.size(1)).to(inputs.device)
        look_ahead_mask = look_ahead_mask.unsqueeze(0).unsqueeze(1)  # [1, 1, seq_len, seq_len]

        # 인코더의 패딩 토큰을 디코더 cross-attention에서 무시하기 위한 마스크
        dec_padding_mask = create_padding_mask(inputs, sp.pad_id())

        # ======================================================
        # (2) 인코더 단계 (Encoder)
        # ======================================================
        # 입력 문장을 벡터로 인코딩
        enc_output = self.encoder(inputs, enc_padding_mask)
        # 출력 형태: [batch_size, src_seq_len, d_model]

        # ======================================================
        # (3) 디코더 단계 (Decoder)
        # ======================================================
        # 인코더 출력과 디코더 입력을 결합하여 예측
        dec_output = self.decoder(
            dec_inputs,        # 이전 단어 입력
            enc_output,        # 인코더 컨텍스트
            look_ahead_mask,   # 자기회귀 마스크
            dec_padding_mask   # 패딩 마스크
        )
        # 출력 형태: [batch_size, tgt_seq_len, d_model]

        # ======================================================
        # (4) 출력 변환 (Final Linear)
        # ======================================================
        # 디코더 출력을 단어 확률 분포(logits)로 변환
        logits = self.final_linear(dec_output)
        # 출력 형태: [batch_size, tgt_seq_len, vocab_size]

        return logits

# %% [markdown]
# ## Step 4-2. Dataset & DataLoader

# %%
class ChatbotDataset(Dataset):
    def __init__(self, qs, ans):
        """
        Args:
            qs (list[list[int]]): 토큰화된 질문 시퀀스 (입력 문장)
            ans (list[list[int]]): 토큰화된 답변 시퀀스 (목표 문장)
        """
        self.qs = qs   # 질문(입력) 시퀀스 리스트
        self.ans = ans # 답변(출력) 시퀀스 리스트

    def __len__(self):
        return len(self.qs)

    def __getitem__(self, i):
        """
        i번째 (질문, 답변) 샘플을 텐서 형태로 반환
        Returns:
            tuple(torch.Tensor, torch.Tensor): (질문 텐서, 답변 텐서)
        """
        return torch.tensor(self.qs[i]), torch.tensor(self.ans[i])


def collate(batch):
    """
    DataLoader가 batch 단위로 데이터를 꺼낼 때 호출되는 함수.

    Args:
        batch (list[tuple[Tensor, Tensor]]): [(src1, tgt1), (src2, tgt2), ...]

    Returns:
        tuple[Tensor, Tensor]:
            src (Tensor): [batch_size, max_src_len] 형태의 인코더 입력
            tgt (Tensor): [batch_size, max_tgt_len] 형태의 디코더 입력
    """
    # batch 내의 (src, tgt) 쌍을 각각 분리
    src, tgt = zip(*batch)

    # -------------------------------
    # 질문 시퀀스 패딩 (Encoder 입력)
    # -------------------------------
    # 길이가 다른 문장들을 동일한 길이로 맞추기 위해 패딩 추가
    # sp.pad_id() : SentencePiece 토크나이저의 패딩 토큰 ID
    src = pad_sequence(src, batch_first=True, padding_value=sp.pad_id())

    # -------------------------------
    # 답변 시퀀스 패딩 (Decoder 입력)
    # -------------------------------
    tgt = pad_sequence(tgt, batch_first=True, padding_value=sp.pad_id())

    # 패딩된 텐서 반환
    return src, tgt



# 전체 데이터셋
full_dataset = ChatbotDataset(tokenized_questions, tokenized_answers)

# 80% train, 10% valid, 10% test
train_size = int(0.8 * len(full_dataset))
valid_size = int(0.1 * len(full_dataset))
test_size = len(full_dataset) - train_size - valid_size

train_dataset, valid_dataset, test_dataset = random_split(
    full_dataset, [train_size, valid_size, test_size],
    generator=torch.Generator().manual_seed(42)
)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate)
valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False, collate_fn=collate)
test_loader  = DataLoader(test_dataset,  batch_size=64, shuffle=False, collate_fn=collate)

print(f"Train: {len(train_dataset)} | Valid: {len(valid_dataset)} | Test: {len(test_dataset)}")
# Out:
# Train: 9458 | Valid: 1182 | Test: 1183

# %% [markdown]
# ## Step 4-3. Model Train

# %%
def get_lr_lambda(d_model, warmup_steps=4000):
    """
    Transformer 논문의 학습률 스케줄링
    lr = d_model^(-0.5) * min(step^(-0.5), step * warmup_steps^(-1.5))
    """
    d_model = float(d_model)
    def lr_lambda(step):
        step = step + 1  # 0-based -> 1-based
        return (d_model ** -0.5) * min(step ** -0.5, step * (warmup_steps ** -1.5))
    return lr_lambda

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
VOCAB_SIZE = sp.get_piece_size()

model = Transformer(
    vocab_size=VOCAB_SIZE,
    num_layers=2,
    units=512,
    d_model=128,
    num_heads=8,
    dropout=0.4, # 과적합으로 규제 강화
    max_len=MAX_LEN
).to(device)

optimizer = optim.AdamW(model.parameters(), lr=1.0, betas=(0.9, 0.98), eps=1e-9)  # lr은 scheduler가 조절
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=get_lr_lambda(d_model=128, warmup_steps=1000))

criterion = nn.CrossEntropyLoss(ignore_index=sp.pad_id(), label_smoothing=0.15) # 과적합으로 규제 강화

# %%
# 모델 저장 경로
os.makedirs("data/chatbot/checkpoints", exist_ok=True)
best_val_loss = float('inf')

# %%
@torch.no_grad()  # 그래디언트 계산 비활성화 (메모리 절약, 속도 향상)
def evaluate(model, loader, crit):
    """
    Args:
        model: 평가할 Transformer 모델
        loader: 검증용 DataLoader
        crit: 손실 함수 (예: nn.CrossEntropyLoss)
    
    Returns:
        float: 검증 데이터셋 평균 손실
    """

    model.eval()

    total_loss = 0.0  # 배치 손실 누적 변수

    for src, tgt in loader:
        src, tgt = src.to(device), tgt.to(device)

        tgt_input = tgt[:, :-1] # 디코더 입력: 마지막 토큰 제외 (teacher forcing)
        tgt_target = tgt[:, 1:].contiguous().view(-1)  # 디코더 목표: 첫 번째 토큰 제외 (예측할 정답)
                                                       # view(-1) → 1차원으로 펼쳐 CrossEntropyLoss 계산 준비
        
        logits = model(src, tgt_input)  # [batch, tgt_seq_len, vocab_size]
        loss = crit(logits.view(-1, VOCAB_SIZE), tgt_target)
        total_loss += loss.item()

    return total_loss / len(loader)

# %%
def train_one_epoch(model, loader, opt, scheduler, crit):
    """
    Args:
        model: 학습할 Transformer 모델
        loader: 학습용 DataLoader
        opt: 옵티마이저 (예: AdamW)
        scheduler: 학습률 스케줄러
        crit: 손실 함수 (예: nn.CrossEntropyLoss)

    Returns:
        float: epoch 단위 평균 손실
    """
    model.train()

    total_loss = 0.0  # 배치 손실 누적 변수

    for step, (src, tgt) in enumerate(loader):
        src, tgt = src.to(device), tgt.to(device)

        tgt_input = tgt[:, :-1] # 디코더 입력: 마지막 토큰 제외 (teacher forcing)

        
        tgt_target = tgt[:, 1:].contiguous().view(-1)  # 디코더 목표: 첫 번째 토큰 제외 (예측할 정답)
                                                       # view(-1) → 1차원으로 펼쳐 CrossEntropyLoss 계산 준비

        opt.zero_grad()
        logits = model(src, tgt_input)  # [batch, tgt_seq_len, vocab_size]
        loss = crit(logits.view(-1, VOCAB_SIZE), tgt_target)
        loss.backward()

        # -------------------------------
        # gradient clipping
        #   - exploding gradient 방지 (최대 L2 norm 1.0)
        # -------------------------------
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        opt.step()
        scheduler.step()

        total_loss += loss.item()

        if (step + 1) % 100 == 0:
            print(f"  Step {step+1} | Loss: {loss.item():.4f} | LR: {scheduler.get_last_lr()[0]:.6f}")

    return total_loss / len(loader)

# %%
N_EPOCHS = 100
for epoch in range(1, N_EPOCHS + 1):
    start = time.time()
    train_loss = train_one_epoch(model, train_loader, optimizer, scheduler, criterion)
    val_loss = evaluate(model, valid_loader, criterion)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), "data/chatbot/checkpoints/best_transformer.pth")
        print(f"  [SAVE] Best model saved | Val Loss: {val_loss:.4f}")

    print(f'Epoch {epoch:02d} | Train: {train_loss:.4f} | Val: {val_loss:.4f} | '
          f'PPL: {math.exp(val_loss):6.2f} | {time.time()-start:.1f}s\n')
# Out:
#   Step 100 | Loss: 6.5827 | LR: 0.000282
#   [SAVE] Best model saved | Val Loss: 6.2387
# Epoch 01 | Train: 7.3831 | Val: 6.2387 | PPL: 512.17 | 3.1s
#
#   Step 100 | Loss: 6.0713 | LR: 0.000696
#   [SAVE] Best model saved | Val Loss: 5.8425
# Epoch 02 | Train: 6.0766 | Val: 5.8425 | PPL: 344.63 | 3.0s
#
#   Step 100 | Loss: 5.4650 | LR: 0.001110
#   [SAVE] Best model saved | Val Loss: 5.5452
# Epoch 03 | Train: 5.7200 | Val: 5.5452 | PPL: 256.00 | 3.0s
#
#   Step 100 | Loss: 5.5579 | LR: 0.001523
#   [SAVE] Best model saved | Val Loss: 5.3296
# Epoch 04 | Train: 5.4399 | Val: 5.3296 | PPL: 206.35 | 3.0s
#
#   Step 100 | Loss: 5.4318 | LR: 0.001937
#   [SAVE] Best model saved | Val Loss: 5.1864
# Epoch 05 | Train: 5.2167 | Val: 5.1864 | PPL: 178.82 | 3.0s
#
#   Step 100 | Loss: 5.0335 | LR: 0.002351
#   [SAVE] Best model saved | Val Loss: 5.1004
# Epoch 06 | Train: 5.0345 | Val: 5.1004 | PPL: 164.08 | 3.1s
#
#   Step 100 | Loss: 4.9812 | LR: 0.002764
#   [SAVE] Best model saved | Val Loss: 5.0406
# Epoch 07 | Train: 4.8959 | Val: 5.0406 | PPL: 154.57 | 3.0s
#
#   Step 100 | Loss: 4.8950 | LR: 0.002621
#   [SAVE] Best model saved | Val Loss: 4.9903
# Epoch 08 | Train: 4.7736 | Val: 4.9903 | PPL: 146.98 | 3.1s
#
#   Step 100 | Loss: 4.7317 | LR: 0.002466
#   [SAVE] Best model saved | Val Loss: 4.9475
# Epoch 09 | Train: 4.6713 | Val: 4.9475 | PPL: 140.82 | 3.0s
#
#   Step 100 | Loss: 4.6097 | LR: 0.002335
#   [SAVE] Best model saved | Val Loss: 4.9193
# Epoch 10 | Train: 4.5810 | Val: 4.9193 | PPL: 136.90 | 3.0s
#
#   Step 100 | Loss: 4.6348 | LR: 0.002223
#   [SAVE] Best model saved | Val Loss: 4.8905
# Epoch 11 | Train: 4.5142 | Val: 4.8905 | PPL: 133.02 | 3.1s
#
#   Step 100 | Loss: 4.3817 | LR: 0.002126
#   [SAVE] Best model saved | Val Loss: 4.8766
# Epoch 12 | Train: 4.4552 | Val: 4.8766 | PPL: 131.19 | 3.0s
#
#   Step 100 | Loss: 4.4235 | LR: 0.002040
#   [SAVE] Best model saved | Val Loss: 4.8628
# Epoch 13 | Train: 4.4004 | Val: 4.8628 | PPL: 129.39 | 3.0s
#
#   Step 100 | Loss: 4.4395 | LR: 0.001964
#   [SAVE] Best model saved | Val Loss: 4.8502
# Epoch 14 | Train: 4.3576 | Val: 4.8502 | PPL: 127.76 | 3.0s
#
#   Step 100 | Loss: 4.4165 | LR: 0.001896
#   [SAVE] Best model saved | Val Loss: 4.8231
# Epoch 15 | Train: 4.3145 | Val: 4.8231 | PPL: 124.35 | 3.0s
#
#   Step 100 | Loss: 4.4530 | LR: 0.001835
#   [SAVE] Best model saved | Val Loss: 4.7991
# Epoch 16 | Train: 4.2744 | Val: 4.7991 | PPL: 121.40 | 2.9s
#
#   Step 100 | Loss: 4.1655 | LR: 0.001779
#   [SAVE] Best model saved | Val Loss: 4.7977
# Epoch 17 | Train: 4.2375 | Val: 4.7977 | PPL: 121.23 | 3.0s
#
#   Step 100 | Loss: 4.2626 | LR: 0.001728
#   [SAVE] Best model saved | Val Loss: 4.7704
# Epoch 18 | Train: 4.2051 | Val: 4.7704 | PPL: 117.96 | 3.1s
#
#   Step 100 | Loss: 4.2217 | LR: 0.001681
#   [SAVE] Best model saved | Val Loss: 4.7702
# Epoch 19 | Train: 4.1782 | Val: 4.7702 | PPL: 117.94 | 3.1s
#
#   Step 100 | Loss: 4.3217 | LR: 0.001638
#   [SAVE] Best model saved | Val Loss: 4.7620
# Epoch 20 | Train: 4.1447 | Val: 4.7620 | PPL: 116.98 | 3.0s
#
#   Step 100 | Loss: 4.2663 | LR: 0.001598
#   [SAVE] Best model saved | Val Loss: 4.7552
# Epoch 21 | Train: 4.1243 | Val: 4.7552 | PPL: 116.19 | 3.1s
#
#   Step 100 | Loss: 4.2092 | LR: 0.001560
#   [SAVE] Best model saved | Val Loss: 4.7429
# Epoch 22 | Train: 4.0960 | Val: 4.7429 | PPL: 114.76 | 3.0s
#
#   Step 100 | Loss: 4.0931 | LR: 0.001526
#   [SAVE] Best model saved | Val Loss: 4.7214
# Epoch 23 | Train: 4.0748 | Val: 4.7214 | PPL: 112.32 | 3.0s
#
#   Step 100 | Loss: 4.0973 | LR: 0.001493
# Epoch 24 | Train: 4.0476 | Val: 4.7256 | PPL: 112.79 | 3.0s
#
#   Step 100 | Loss: 4.0100 | LR: 0.001462
#   [SAVE] Best model saved | Val Loss: 4.7106
# Epoch 25 | Train: 4.0296 | Val: 4.7106 | PPL: 111.12 | 3.0s
#
#   Step 100 | Loss: 4.1507 | LR: 0.001434
# Epoch 26 | Train: 4.0067 | Val: 4.7111 | PPL: 111.18 | 3.0s
#
#   Step 100 | Loss: 3.8466 | LR: 0.001407
#   [SAVE] Best model saved | Val Loss: 4.7079
# Epoch 27 | Train: 3.9848 | Val: 4.7079 | PPL: 110.81 | 2.9s
#
#   Step 100 | Loss: 3.8856 | LR: 0.001381
#   [SAVE] Best model saved | Val Loss: 4.6911
# Epoch 28 | Train: 3.9711 | Val: 4.6911 | PPL: 108.98 | 3.1s
#
#   Step 100 | Loss: 4.0404 | LR: 0.001357
#   [SAVE] Best model saved | Val Loss: 4.6857
# Epoch 29 | Train: 3.9498 | Val: 4.6857 | PPL: 108.38 | 3.0s
#
#   Step 100 | Loss: 4.0524 | LR: 0.001334
# Epoch 30 | Train: 3.9328 | Val: 4.6877 | PPL: 108.60 | 3.0s
#
#   Step 100 | Loss: 3.9297 | LR: 0.001312
#   [SAVE] Best model saved | Val Loss: 4.6789
# Epoch 31 | Train: 3.9189 | Val: 4.6789 | PPL: 107.65 | 3.1s
#
#   Step 100 | Loss: 3.9563 | LR: 0.001291
# Epoch 32 | Train: 3.9032 | Val: 4.6842 | PPL: 108.22 | 2.9s
#
#   Step 100 | Loss: 3.9576 | LR: 0.001271
# Epoch 33 | Train: 3.8877 | Val: 4.6830 | PPL: 108.10 | 3.0s
#
#   Step 100 | Loss: 3.8126 | LR: 0.001252
# Epoch 34 | Train: 3.8687 | Val: 4.6793 | PPL: 107.70 | 3.0s
#
#   Step 100 | Loss: 3.8726 | LR: 0.001234
#   [SAVE] Best model saved | Val Loss: 4.6706
# Epoch 35 | Train: 3.8653 | Val: 4.6706 | PPL: 106.76 | 3.0s
#
#   Step 100 | Loss: 4.0773 | LR: 0.001216
#   [SAVE] Best model saved | Val Loss: 4.6669
# Epoch 36 | Train: 3.8481 | Val: 4.6669 | PPL: 106.37 | 3.0s
#
#   Step 100 | Loss: 3.9187 | LR: 0.001200
#   [SAVE] Best model saved | Val Loss: 4.6643
# Epoch 37 | Train: 3.8363 | Val: 4.6643 | PPL: 106.09 | 3.1s
#
#   Step 100 | Loss: 3.8287 | LR: 0.001184
#   [SAVE] Best model saved | Val Loss: 4.6493
# Epoch 38 | Train: 3.8193 | Val: 4.6493 | PPL: 104.52 | 3.1s
#
#   Step 100 | Loss: 3.8080 | LR: 0.001168
#   [SAVE] Best model saved | Val Loss: 4.6459
# Epoch 39 | Train: 3.8162 | Val: 4.6459 | PPL: 104.16 | 2.9s
#
#   Step 100 | Loss: 3.8746 | LR: 0.001153
#   [SAVE] Best model saved | Val Loss: 4.6439
# Epoch 40 | Train: 3.8027 | Val: 4.6439 | PPL: 103.95 | 3.0s
#
#   Step 100 | Loss: 3.7354 | LR: 0.001139
#   [SAVE] Best model saved | Val Loss: 4.6418
# Epoch 41 | Train: 3.7903 | Val: 4.6418 | PPL: 103.74 | 3.2s
#
#   Step 100 | Loss: 3.7925 | LR: 0.001125
# Epoch 42 | Train: 3.7773 | Val: 4.6455 | PPL: 104.11 | 3.0s
#
#   Step 100 | Loss: 3.8006 | LR: 0.001112
#   [SAVE] Best model saved | Val Loss: 4.6279
# Epoch 43 | Train: 3.7743 | Val: 4.6279 | PPL: 102.30 | 3.0s
#
#   Step 100 | Loss: 3.8689 | LR: 0.001099
# Epoch 44 | Train: 3.7597 | Val: 4.6362 | PPL: 103.15 | 3.0s
#
#   Step 100 | Loss: 3.7009 | LR: 0.001087
# Epoch 45 | Train: 3.7508 | Val: 4.6308 | PPL: 102.60 | 2.9s
#
#   Step 100 | Loss: 3.7676 | LR: 0.001075
# Epoch 46 | Train: 3.7385 | Val: 4.6390 | PPL: 103.44 | 3.1s
#
#   Step 100 | Loss: 3.6943 | LR: 0.001063
# Epoch 47 | Train: 3.7332 | Val: 4.6303 | PPL: 102.55 | 2.9s
#
#   Step 100 | Loss: 3.6845 | LR: 0.001052
#   [SAVE] Best model saved | Val Loss: 4.6209
# Epoch 48 | Train: 3.7224 | Val: 4.6209 | PPL: 101.59 | 3.1s
#
#   Step 100 | Loss: 3.8064 | LR: 0.001041
# Epoch 49 | Train: 3.7182 | Val: 4.6274 | PPL: 102.25 | 2.9s
#
#   Step 100 | Loss: 3.7057 | LR: 0.001031
# Epoch 50 | Train: 3.7046 | Val: 4.6331 | PPL: 102.83 | 3.0s
#
#   Step 100 | Loss: 3.7518 | LR: 0.001021
# Epoch 51 | Train: 3.6997 | Val: 4.6257 | PPL: 102.08 | 3.0s
#
#   Step 100 | Loss: 3.6031 | LR: 0.001011
# Epoch 52 | Train: 3.6925 | Val: 4.6260 | PPL: 102.11 | 3.0s
#
#   Step 100 | Loss: 3.6823 | LR: 0.001001
# Epoch 53 | Train: 3.6912 | Val: 4.6213 | PPL: 101.63 | 2.9s
#
#   Step 100 | Loss: 3.6380 | LR: 0.000992
#   [SAVE] Best model saved | Val Loss: 4.6153
# Epoch 54 | Train: 3.6789 | Val: 4.6153 | PPL: 101.02 | 3.1s
#
#   Step 100 | Loss: 3.7178 | LR: 0.000983
#   [SAVE] Best model saved | Val Loss: 4.6136
# Epoch 55 | Train: 3.6683 | Val: 4.6136 | PPL: 100.85 | 3.0s
#
#   Step 100 | Loss: 3.5288 | LR: 0.000974
# Epoch 56 | Train: 3.6644 | Val: 4.6315 | PPL: 102.67 | 2.9s
#
#   Step 100 | Loss: 3.7655 | LR: 0.000965
#   [SAVE] Best model saved | Val Loss: 4.6136
# Epoch 57 | Train: 3.6538 | Val: 4.6136 | PPL: 100.84 | 3.0s
#
#   Step 100 | Loss: 3.7245 | LR: 0.000957
# Epoch 58 | Train: 3.6499 | Val: 4.6181 | PPL: 101.30 | 3.0s
#
#   Step 100 | Loss: 3.7072 | LR: 0.000948
#   [SAVE] Best model saved | Val Loss: 4.6031
# Epoch 59 | Train: 3.6453 | Val: 4.6031 | PPL:  99.79 | 3.0s
#
#   Step 100 | Loss: 3.7011 | LR: 0.000940
# Epoch 60 | Train: 3.6447 | Val: 4.6056 | PPL: 100.04 | 3.0s
#
#   Step 100 | Loss: 3.5479 | LR: 0.000933
# Epoch 61 | Train: 3.6312 | Val: 4.6092 | PPL: 100.41 | 2.9s
#
#   Step 100 | Loss: 3.7351 | LR: 0.000925
# Epoch 62 | Train: 3.6157 | Val: 4.6150 | PPL: 100.99 | 2.9s
#
#   Step 100 | Loss: 3.5605 | LR: 0.000918
#   [SAVE] Best model saved | Val Loss: 4.5994
# Epoch 63 | Train: 3.6189 | Val: 4.5994 | PPL:  99.43 | 3.0s
#
#   Step 100 | Loss: 3.6808 | LR: 0.000910
# Epoch 64 | Train: 3.6103 | Val: 4.6017 | PPL:  99.65 | 3.1s
#
#   Step 100 | Loss: 3.5964 | LR: 0.000903
# Epoch 65 | Train: 3.6092 | Val: 4.6005 | PPL:  99.54 | 2.9s
#
#   Step 100 | Loss: 3.6412 | LR: 0.000896
# Epoch 66 | Train: 3.5963 | Val: 4.6012 | PPL:  99.60 | 3.0s
#
#   Step 100 | Loss: 3.6612 | LR: 0.000890
#   [SAVE] Best model saved | Val Loss: 4.5958
# Epoch 67 | Train: 3.5984 | Val: 4.5958 | PPL:  99.07 | 3.0s
#
#   Step 100 | Loss: 3.6151 | LR: 0.000883
#   [SAVE] Best model saved | Val Loss: 4.5942
# Epoch 68 | Train: 3.5910 | Val: 4.5942 | PPL:  98.91 | 3.2s
#
#   Step 100 | Loss: 3.6034 | LR: 0.000877
#   [SAVE] Best model saved | Val Loss: 4.5936
# Epoch 69 | Train: 3.5841 | Val: 4.5936 | PPL:  98.85 | 3.0s
#
#   Step 100 | Loss: 3.6730 | LR: 0.000870
# Epoch 70 | Train: 3.5842 | Val: 4.5985 | PPL:  99.34 | 2.9s
#
#   Step 100 | Loss: 3.6316 | LR: 0.000864
# Epoch 71 | Train: 3.5709 | Val: 4.6021 | PPL:  99.69 | 3.0s
#
#   Step 100 | Loss: 3.5642 | LR: 0.000858
# Epoch 72 | Train: 3.5676 | Val: 4.5975 | PPL:  99.24 | 3.0s
#
#   Step 100 | Loss: 3.5771 | LR: 0.000852
# Epoch 73 | Train: 3.5610 | Val: 4.5990 | PPL:  99.38 | 2.9s
#
#   Step 100 | Loss: 3.5049 | LR: 0.000846
#   [SAVE] Best model saved | Val Loss: 4.5919
# Epoch 74 | Train: 3.5603 | Val: 4.5919 | PPL:  98.68 | 3.1s
#
#   Step 100 | Loss: 3.4890 | LR: 0.000841
# Epoch 75 | Train: 3.5522 | Val: 4.5946 | PPL:  98.95 | 2.9s
#
#   Step 100 | Loss: 3.6583 | LR: 0.000835
#   [SAVE] Best model saved | Val Loss: 4.5885
# Epoch 76 | Train: 3.5517 | Val: 4.5885 | PPL:  98.35 | 3.0s
#
#   Step 100 | Loss: 3.5446 | LR: 0.000830
# Epoch 77 | Train: 3.5475 | Val: 4.5910 | PPL:  98.59 | 3.0s
#
#   Step 100 | Loss: 3.4758 | LR: 0.000824
# Epoch 78 | Train: 3.5454 | Val: 4.5891 | PPL:  98.40 | 3.1s
#
#   Step 100 | Loss: 3.6560 | LR: 0.000819
# Epoch 79 | Train: 3.5301 | Val: 4.5896 | PPL:  98.45 | 2.9s
#
#   Step 100 | Loss: 3.3902 | LR: 0.000814
# Epoch 80 | Train: 3.5327 | Val: 4.5957 | PPL:  99.06 | 2.9s
#
#   Step 100 | Loss: 3.6436 | LR: 0.000809
# Epoch 81 | Train: 3.5290 | Val: 4.5984 | PPL:  99.33 | 3.1s
#
#   Step 100 | Loss: 3.6322 | LR: 0.000804
# Epoch 82 | Train: 3.5245 | Val: 4.5937 | PPL:  98.86 | 3.0s
#
#   Step 100 | Loss: 3.6231 | LR: 0.000799
# Epoch 83 | Train: 3.5207 | Val: 4.5922 | PPL:  98.71 | 2.9s
#
#   Step 100 | Loss: 3.5975 | LR: 0.000794
#   [SAVE] Best model saved | Val Loss: 4.5841
# Epoch 84 | Train: 3.5135 | Val: 4.5841 | PPL:  97.92 | 3.3s
#
#   Step 100 | Loss: 3.6730 | LR: 0.000790
# Epoch 85 | Train: 3.5099 | Val: 4.5918 | PPL:  98.67 | 2.9s
#
#   Step 100 | Loss: 3.4845 | LR: 0.000785
# Epoch 86 | Train: 3.5058 | Val: 4.5943 | PPL:  98.92 | 3.0s
#
#   Step 100 | Loss: 3.6076 | LR: 0.000780
# Epoch 87 | Train: 3.5103 | Val: 4.5889 | PPL:  98.38 | 3.0s
#
#   Step 100 | Loss: 3.5806 | LR: 0.000776
# Epoch 88 | Train: 3.5017 | Val: 4.5916 | PPL:  98.65 | 3.0s
#
#   Step 100 | Loss: 3.5283 | LR: 0.000772
#   [SAVE] Best model saved | Val Loss: 4.5739
# Epoch 89 | Train: 3.4947 | Val: 4.5739 | PPL:  96.92 | 3.0s
#
#   Step 100 | Loss: 3.6082 | LR: 0.000767
# Epoch 90 | Train: 3.4937 | Val: 4.5903 | PPL:  98.52 | 3.0s
#
#   Step 100 | Loss: 3.6050 | LR: 0.000763
# Epoch 91 | Train: 3.4937 | Val: 4.5926 | PPL:  98.75 | 3.0s
#
#   Step 100 | Loss: 3.4669 | LR: 0.000759
# Epoch 92 | Train: 3.4890 | Val: 4.5855 | PPL:  98.06 | 2.9s
#
#   Step 100 | Loss: 3.5337 | LR: 0.000755
# Epoch 93 | Train: 3.4819 | Val: 4.5785 | PPL:  97.37 | 2.9s
#
#   Step 100 | Loss: 3.4383 | LR: 0.000751
# Epoch 94 | Train: 3.4861 | Val: 4.5779 | PPL:  97.31 | 3.1s
#
#   Step 100 | Loss: 3.7083 | LR: 0.000747
# Epoch 95 | Train: 3.4739 | Val: 4.5894 | PPL:  98.43 | 2.9s
#
#   Step 100 | Loss: 3.3577 | LR: 0.000743
# Epoch 96 | Train: 3.4736 | Val: 4.5746 | PPL:  96.99 | 3.0s
#
#   Step 100 | Loss: 3.3594 | LR: 0.000739
# Epoch 97 | Train: 3.4704 | Val: 4.5750 | PPL:  97.03 | 2.9s
#
#   Step 100 | Loss: 3.5465 | LR: 0.000735
# Epoch 98 | Train: 3.4675 | Val: 4.5741 | PPL:  96.94 | 3.0s
#
#   Step 100 | Loss: 3.4414 | LR: 0.000731
# Epoch 99 | Train: 3.4577 | Val: 4.5876 | PPL:  98.26 | 3.0s
#
#   Step 100 | Loss: 3.4677 | LR: 0.000728
#   [SAVE] Best model saved | Val Loss: 4.5668
# Epoch 100 | Train: 3.4567 | Val: 4.5668 | PPL:  96.23 | 3.0s

# %% [markdown]
# # Step 5. 모델 평가하기

# %%
model.load_state_dict(torch.load("data/chatbot/checkpoints/best_transformer.pth"))
print("Best model loaded.\n")

test_loss = evaluate(model, test_loader, criterion)
print(f"=== FINAL TEST LOSS: {test_loss:.4f} | PPL: {math.exp(test_loss):6.2f} ===\n")
# Out:
# Best model loaded.
#
# === FINAL TEST LOSS: 4.7472 | PPL: 115.27 ===

# %%
@torch.no_grad()  # 추론 시 그래디언트 계산 비활성화 (메모리 절약, 속도 향상)
def respond(model, sp, sentence, max_len=50):
    """
    Args:
        model: 학습된 Transformer 모델
        sp: SentencePiece 토크나이저 객체
        sentence: 사용자 입력 문장 (str)
        max_len: 생성할 최대 토큰 길이
    
    Returns:
        str: 모델이 생성한 답변 문장
    """
    
    model.eval()
    src = torch.tensor([sp.encode_as_ids(sentence)], device=device)  # [1, src_seq_len]
    enc_padding_mask = create_padding_mask(src, sp.pad_id())
    enc_output = model.encoder(src, enc_padding_mask)  # [1, src_seq_len, d_model]

    dec_input = torch.tensor([[sp.bos_id()]], device=device)  # [1, 1]
    output_ids = []  # 생성된 토큰 ID를 저장할 리스트

    for _ in range(max_len):

 
        look_ahead_mask = create_look_ahead_mask(dec_input.size(1)).to(device)
        look_ahead_mask = look_ahead_mask.unsqueeze(0).unsqueeze(1)  # [1, 1, seq_len, seq_len]
        dec_padding_mask = create_padding_mask(src, sp.pad_id())
        dec_output = model.decoder(dec_input, enc_output, look_ahead_mask, dec_padding_mask)  # [1, seq_len, d_model]
        logits = model.final_linear(dec_output[:, -1, :])  # [1, vocab_size]
        next_id = logits.argmax(dim=-1).item()  # 가장 확률 높은 토큰 선택 (greedy decoding)
        output_ids.append(next_id)

        if next_id == sp.eos_id():
            break
        dec_input = torch.cat([dec_input, torch.tensor([[next_id]], device=device)], dim=1)  # [1, seq_len+1]

    return sp.decode_ids(output_ids)

# %%
test_indices = test_dataset.indices  # 원본 df에서의 인덱스 리스트
test_questions = [df.Q[idx] for idx in test_indices]
test_answers   = [df.A[idx] for idx in test_indices]

for i in range(len(test_questions)):
    q = test_questions[i]
    real_a = test_answers[i]
    pred_a = respond(model, sp, q)

    print(f"\nQ: {q}")
    print(f"실제 A: {real_a}")
    print(f"모델 A: {pred_a}")
# Out:
# Q: 둘 다 바보였다
# 실제 A: 바보의 사랑이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 일만 하고 살았는데 이 모양
# 실제 A: 자신의 인생을 사세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 쉬는날인데 왜 만나자고 안하지
# 실제 A: 직접 만나자고 연락해보세요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아닐 거예요 .
#
# Q: 비정규직이라 차별받아
# 실제 A: 차별이 가장 안 좋은 건데 슬프네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 오늘도 공기가 뿌얘
# 실제 A: 마스크 착용 하시고 외출하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 만난지 얼마 안됐는데 고백받았어
# 실제 A: 정말 좋아했나봐요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 파마할까
# 실제 A: 한번 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 젊어지고 싶어
# 실제 A: 마음이라도 어리게 사세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 자기 소개 또 어떻게 해
# 실제 A: 강렬하고 자신감있게 하면 되지 않을까싶어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 그게 잘 안되네.
# 실제 A: 마음이 쉽지 않죠.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 그녀는 나를 어떻게 생각할까?
# 실제 A: 아직은 잘 모르겠어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 답정녀 좀 싫어
# 실제 A: 못 이기니 피할 수 있으면 피하세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 지금이 겨울이라 참 다행이이네
# 실제 A: 제가 곁에 있을게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 씁쓸하네.
# 실제 A: 제가 있잖아요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 짝남의 여사친들 보기 질투나.
# 실제 A: 질투난다고 살짝 말해봐요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 그녀의 환심을 살 수 있는 방법이 뭐가 있을까?
# 실제 A: 그녀가 좋아하는게 뭔지 찾아봐요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 사랑해서 너무 행복해
# 실제 A: 어쩐지 행복해 보이더라구요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 미친것같아
# 실제 A: 답답한 일이 있었나봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 출퇴근 시간이 좀 줄어들었으면 좋겠다
# 실제 A: 대중교통을 이용해 보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한심하네ㅜㅜ
# 실제 A: 자책하지 말아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 끝인거겠죠?
# 실제 A: 언젠간 올 시기였을거예요.
# 모델 A: 좋은 만남이었길 바라요 .
#
# Q: 좋아하는 여자에 프사가.
# 실제 A: 신경쓰이나봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 비싼 명품 이제 그만 사야겠어
# 실제 A: 남의 눈을 위한 거라면 필요 없어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 습관을 고치기 어려워
# 실제 A: 고치기 어려우니까 습관이라고 하겠죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 야근각
# 실제 A: 오늘도 고생이 많으시네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 나 좀 잘생겨 보인다.
# 실제 A: 자신에게 콩깍지가 씌였나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 미팅 할까 말까
# 실제 A: 만남은 다 좋죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 맘속으로 조금씩 정리가 돼가네
# 실제 A: 다행이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 웃겨 줘
# 실제 A: 지금 당장 거울 앞에 서 보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 셀프 신행준비 팁 알려줘
# 실제 A: 신혼여행은 자유여행이죠!
# 모델 A: 좋은 생각이에요 .
#
# Q: 시험인데 집중 안돼
# 실제 A: 딴 생각 하지마세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 나 오늘 따라 잘생겨 보이네
# 실제 A: 자신에게 콩깍지가 씌였나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 부모님 선물 추천.
# 실제 A: 같이 여행을 떠나보세요.
# 모델 A: 뭘 입어도 멋져요 .
#
# Q: 헤어진지 1달 정도 되었습니다
# 실제 A: 잘 지내고 있는 것 같네요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 짝남이 좋아하는애 있거나 여친 있으면 포기하는 이유가 뭐야?
# 실제 A: 그 사람에 대한 예의일 것 같아요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 새로운여자가 생긴걸까?
# 실제 A: 궁금해하지도 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 벨이 울리는 걸 기다려
# 실제 A: 기다리는 전화가 있나봐요.
# 모델 A: 그게 인생이죠 .
#
# Q: 지쳐서 헤어지자고 한 남자도 후폭풍올까?
# 실제 A: 모든 이별에는 후유증이 있기 마련이니까요.
# 모델 A: 그게 인생이죠 .
#
# Q: 대리효도 짜증
# 실제 A: 진짜 아니네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 자격증 따야하나
# 실제 A: 뭐든 좋죠.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 노래 잘하고 싶어
# 실제 A: 저도 부러워요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 남자친구가 나쁜 의도는 아닌데 표현이 너무 서툴러.
# 실제 A: 더 좋은 표현들로 천천히 고쳐나가봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 아빠가 담배 그만 피웠으면
# 실제 A: 금연 프로그램을 소개해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 뭐 재미있는거 하는 날인가
# 실제 A: 오늘은 예능이요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 예능도 이제 재미없어
# 실제 A: 잘 찾아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 감정을 혼자서 정리할 수 있을까요?
# 실제 A: 본인이 하기 나름일 거예요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 나 보고 잘 웃는 여자애 나 좋아하는 건가?
# 실제 A: 직접 알아보는 것이 좋아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 뭔 비밀이 그렇게 많은지
# 실제 A: 하나씩 비밀을 공유해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 가족이 아니지만 가족같은.
# 실제 A: 가족이 될 사람일지도 모르죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸타다 끝났나
# 실제 A: 지금 연락해보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 그사람은지금대전에있습니다
# 실제 A: 신경쓰지 마세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 잘 참았어
# 실제 A: 잘하고 있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 답례품 뭐하지?
# 실제 A: 마음으로 충분할 거예요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 가스비 너무 많이 나왔다.
# 실제 A: 다음 달에는 더 절약해봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 그녀를 떠나보내야 하나?
# 실제 A: 고민하고 있다면 그게 맞을거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 차단당했네
# 실제 A: 잊는 데는 더 도움이 될지도 몰라요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 사랑이 영원할 거라 믿고 싶어
# 실제 A: 믿으면 이루어져요.
# 모델 A: 그게 인생이죠 .
#
# Q: 완전히 정리했어
# 실제 A: 조금 후련해졌길 바랍니다.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 정말잊어보려고 모든수단을 동원했지만.
# 실제 A: 문득 생각나고 잊혀지지 않나봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 썸 타니까 연락에 집착하게 돼.
# 실제 A: 자연스러운 현상이에요.
# 모델 A: 마음이 복잡하겠어요 .
#
# Q: 선이 많이 들어오네
# 실제 A: 많이 만나보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 노는 것 좋아하는 여자 이쁜데 좀 그래.
# 실제 A: 자신의 가치관에 상대를 속박하지 말아요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 사랑하는 사람이랑 살고싶어
# 실제 A: 행복한 상상은 현실에 반영된다고 해요.
# 모델 A: 그게 인생이죠 .
#
# Q: 마음이 변할까봐 두려워
# 실제 A: 서로에게 믿음을 주세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자들이 좋아하는 남자 특징?
# 실제 A: 다정한게 좋을 듯 해요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 만나는데 혈액형이 중요해?
# 실제 A: 전혀 중요하지 않아요.
# 모델 A: 그게 인생이죠 .
#
# Q: 매달렸다 차였어
# 실제 A: 그래도 미련은 없을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸녀 태도가 짜증남
# 실제 A: 고칠 수 있는지 생각해보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 폭언하는 사람 어떻게 해?
# 실제 A: 그 사람 말고 저랑 수다 떨어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 결혼은 하고 싶은데 며느리는 되기 싫어
# 실제 A: 그럼 어머니가 없는 남자를 만나서 결혼하세요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 그는 지금 무슨 생각을 할까?
# 실제 A: 연락을 해보세요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 자면 안되는데 또 잤어
# 실제 A: 피곤했나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝녀가 졸업하는데 어떤 꽃을 선물하면 좋아할까?
# 실제 A: 길거리에 있는 꽃다발 말고 예약해보세요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 오토바이 있었으면 좋겠다
# 실제 A: 한푼 두푼 모아서 사보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 술 먹을 줄 알아?
# 실제 A: 저는 주당이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 부산 갈까?
# 실제 A: 여행은 항상 좋죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 4년 연애 후 이별 6개월. 새로운 시작을 하는 전여친. 너무 힘들어.
# 실제 A: 헤어지면 남이에요. 신경쓰면 더 힘들어져요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 친한 동생인데 짝사랑하는 것 같습니다.
# 실제 A: 남녀 사이에서 있을 수 있는 일입니다.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 상처받았어
# 실제 A: 다른 사람 말은 신경쓰지 마세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 내 번호를 따간 사람이 내 친구가 좋아하는 애야.
# 실제 A: 운명의 장난같네요.
# 모델 A: 마음이 복잡하겠어요 .
#
# Q: 이런 내가 너무 싫어
# 실제 A: 싫어하지 말아요.
# 모델 A: 그게 인생이죠 .
#
# Q: 오늘 운이 안 좋았어
# 실제 A: 다른 곳에 쓰려고 운을 아껴뒀나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 비많이오네~
# 실제 A: 감기 조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 돈 다 없어졌어
# 실제 A: 새는 돈을 막아보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 김치도 없네
# 실제 A: 마트 갑시다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 미쳐
# 실제 A: 그럴만 해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 돈 안드는 데이트 코스
# 실제 A: 등산 데이트를 해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝녀한테 잘 보이고 싶은데.
# 실제 A: 자신감을 가지세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내가 싫은 건 너도 싫어해줘서 고마워
# 실제 A: 싫은 게 통해야 편하죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 헤어질때의 모습이 그 사람의 진짜 모습
# 실제 A: 그 모습도 그 사람의 부분이에요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 키 컸으면
# 실제 A: 지금도 충분해요.
# 모델 A: 맛있게 드세요 .
#
# Q: 계속 맴돈다.
# 실제 A: 한동안은 그럴거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내 집이 생겼어
# 실제 A: 내 집 마련 축하드려요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸인지 아닌지
# 실제 A: 연락을 이어가면서 알아보셔요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 싸울 때 내가 아는 사람이 맞나 싶어
# 실제 A: 본 모습일지도 몰라요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 결국 핸드폰 번호 바꿨어
# 실제 A: 이제 연락 하지 마세요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 상 좀 받아야 할텐데
# 실제 A: 다음에는 받을 수 있을 거예요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 중소기업이라도 취직할까?
# 실제 A: 일하는 것 자체가 중요하죠.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 여자친구가 화나면 말을 안 해.
# 실제 A: 시간을 주세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 데이트하고 보통 몇시쯤에 집에 들어가?
# 실제 A: 막차 타고 집에 오죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 꽃놀이 가고 싶어
# 실제 A: 벚꽃 계절이 다가왔네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 군대가기 전인데 썸녀한테 고백해도 될까
# 실제 A: 상대방이 부담을 느낄지 생각해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 피씨방 가자고 말해볼까?
# 실제 A: 말해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아하는 선배가 있는데 선톡오게 하는 방법 좀.
# 실제 A: 먼저 연락해서 대화를 이어나가는게 더 좋습니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 아따 엿먹일 방법 없나
# 실제 A: 증오는 부메랑이 되어 돌아올 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 미련인건가.? 바보인건가
# 실제 A: 이별 그렇게 만들더라고요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 뭘해도
# 실제 A: 생각이 날 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 썸남이 짝남 됐어요. 위로해 주세요.
# 실제 A: 맘고생 많았어요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 고작 그러려고 날 떠난건지
# 실제 A: 그럴 줄 몰랐을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 살며시 다가왔어
# 실제 A: 가랑비에 옷 젖는 듯한 사랑이었나봐요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 커피 마시고 싶어
# 실제 A: 카페인이 필요한 시간인가 봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 되게 건조하네
# 실제 A: 눈을 깜빡거려 보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나만 힘든가 보네
# 실제 A: 마음이 약해 탈이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남자친구에게 힘들때 어떻게해?
# 실제 A: 의지하는 편이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 쉬는 중입니다.
# 실제 A: 휴식도 필요하죠.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 말이 안 통해
# 실제 A: 대화의 눈높이가 맞는 사람 만나세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 오늘 기분을 뭐라고 해야하나
# 실제 A: 좋았으면 좋겠네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 나도 이제 아재인가
# 실제 A: 고민하고 있으면 그럴 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 위로가 되는 좋은글이 있어 올려
# 실제 A: 고마워요. 저한테도 위로가 될 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구와 첫키스는 언제했어?
# 실제 A: 뭐 이런 걸 물어보시나요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 썸에서 연인될 수 있을까
# 실제 A: 썸 타다가 연인 되는 게 일반적이죠.
# 모델 A: 최대한 이해해보세요 .
#
# Q: 아직도 기억 속에 생생한데
# 실제 A: 사랑은 희미해져 가네요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 스케일링 하기 귀찮아
# 실제 A: 주기적으로 해주면 좋대요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 나 그지임
# 실제 A: 밥 사줄 친구를 찾아 보세요~
# 모델 A: 좋은 생각이에요 .
#
# Q: 2주가지나가네
# 실제 A: 시간이 더 많이 지나가길 바랄게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 자기 전에 통화하면 썸이야?
# 실제 A: 호감이 없으면 통화를 안 할 거예요.
# 모델 A: 최대한 이해해보세요 .
#
# Q: 드디어 처음으로 꿈에 나욌습니다.
# 실제 A: 많이 생각했나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 회사에서 어쩔수없이 보고 왔습니다
# 실제 A: 당신의 잘못이 아니에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 춘곤증인가봐 졸려
# 실제 A: 잠깐 주무세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 열심히 할거야
# 실제 A: 좋은 태도네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 볼링 치고 놀았어
# 실제 A: 재밌겠어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짧은연애인데 미련때문에 연락을 할지말지 ㅠ.ㅠ
# 실제 A: 사랑이 아닌 미련이라면 연락하지 말아요.
# 모델 A: 마음이 허전하신가봐요 .
#
# Q: 장거리 썸 고백해도될까
# 실제 A: 많이 만나보는 게 좋겠지만 연락을 더 자주 해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 스키 첨 타 봤어.
# 실제 A: 강습 받아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내일 모의평가다
# 실제 A: 공부한 만큼 나올 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이제 봄인가봐
# 실제 A: 날씨가 많이 풀렸죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 그리워서 죽고 싶다는 생각이 드네.
# 실제 A: 무서운 생각하지마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나도 좋아하는 사람이랑 놀러가고 싶어.
# 실제 A: 용기를 내서 말해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 신발 새로 샀다
# 실제 A: 좋은 곳으로 데려다 줄 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 데이트로 놀이공원 가는거 어때?
# 실제 A: 데이트하기 좋은 곳이죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 고백한 애가 연락이 느려.
# 실제 A: 바쁘거나 감정의 변화가 생겼을지도 모르겠어요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 난 안돼 난 못 받아들여 제발
# 실제 A: 이제 현실을 받아들이세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 물건들 버려야지
# 실제 A: 버리는게 후련할지도 몰라요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 그쪽은 너무 편안하고 즐겁게 지내.
# 실제 A: 자신이 편하고 즐거울 수 있는 방법을 생각해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸인데 떠보는 거 같아요
# 실제 A: 돌직구를 날릴 차례인 것 같습니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 내가 좋아하는 사람이 나를 좋아하는지 모르겠어.
# 실제 A: 주변에 물어보는 건 어떨까요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 좋은 대학 나온 거 부러워
# 실제 A: 다른 능력을 채워보세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 화장실을 어떻게 참아?
# 실제 A: 장이 예민한가봐요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 그냥 보고싶다
# 실제 A: 아련하네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 얼마전에 욕 이빠이 하고 다 끝냈는데.
# 실제 A: 미련이 남지 않았길 바랍니다.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 좋아하는 사람 잊는 방법 조언 좀.
# 실제 A: 가슴 아픈 질문이네요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 썸 탔던 애 친구해도 되나
# 실제 A: 소극적으로 표현했다면 친구해도 좋을 것 같습니다.
# 모델 A: 최대한 이해해보세요 .
#
# Q: 너무 힘들어서 심장이 터질 것만 같아
# 실제 A: 심호흡 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어진 사람은 벌써 새여친 생겼네!!
# 실제 A: 이젠 그녀를 놓아주세요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 덕질 하는 중
# 실제 A: 좋아하는 게 있는 건 더없이 좋은 일이에요.
# 모델 A: 그게 인생이죠 .
#
# Q: 이게 바로 첫사랑인듯
# 실제 A: 당신의 소중한 사랑을 이루어 보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 늦게 까지 술 먹나 보다
# 실제 A: 몸에 해로우니 적게 먹는 게 좋겠다고 말해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 3개월이라는 시간이 흘렀지만 여전히 제자리걸음
# 실제 A: 제자리여도 괜찮아요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 이별을 앞둔 이들에게
# 실제 A: 조언해주세요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 만난지 200일됐어
# 실제 A: 알콩달콩 사랑할 때네요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 썸 타는 사람 있는데 망설여지는데
# 실제 A: 어떤 부분이 망설여지는지 말씀해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 네가 죽는다는 꿈을 꾸었어
# 실제 A: 꿈조차 힘들겠지만 괜찮아질 거예요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 언젠가 하는 거죠
# 실제 A: 언젠간 할 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 좋아하게 만들고 싶다
# 실제 A: 제가 당신을 좋아하고 있어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 맞지 않더라도 대화로 잘맞아갈수 있을까?
# 실제 A: 서로 배려하면 가능하죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 용돈 넘 적어
# 실제 A: 올려달라고 말해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아하는 사람이랑 벚꽃구경 가고 싶어.
# 실제 A: 상황을 봐서 연락해 봐요.
# 모델 A: 최대한 이해해보세요 .
#
# Q: 더 격렬하게 아무 것도 안하고 싶다.
# 실제 A: 아무것도 하지마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 왜 이렇게 돈이 없지
# 실제 A: 슬프네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 베터리 충전기도 안 가져 왔네
# 실제 A: 충전할 곳을 찾아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 사람이 생기면 좋을 줄 알았는데 우울하기만 해.
# 실제 A: 사랑이 내 맘같지 않으니까요.
# 모델 A: 마음이 복잡하겠어요 .
#
# Q: 낭만이라고는 없어가지구
# 실제 A: 낭만적인 거 좋아하시는구나!
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 남친이랑 대화가 잘 돼서 좋아
# 실제 A: 말 통하는 게 중요하죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 무섭습니다
# 실제 A: 누구도 해치지 않아요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 휴 전남친 흔적찾기
# 실제 A: 찾으려고 노력하지 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 자꾸 다시 만나게 되는데 무슨 방법이 좋을까
# 실제 A: 행동반경이 비슷한가봅니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 헤어지려고 합니다
# 실제 A: 힘든 결정 하셨네요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 내가 연락 끊은 짝남한테 다시 연락올 수 있는 법 좀.
# 실제 A: 먼저 연락해서 대화를 이어나가는 게 수월해요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 집들이 하라네
# 실제 A: 하고 안하고는 집주인 마음이죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 넋두리
# 실제 A: 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 너무 기대했나봐
# 실제 A: 아무것도 바라지 않을 때 천하를 얻는다는 말이 있어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 나 좀 사랑해줘
# 실제 A: 사랑합니다!
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 모르는 사이에 좋아하는 티 내는 법 알려주세요.
# 실제 A: 사소한 걸 기억해서 말을 걸어보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 저한테만 장난치는 남자애가 나 좋아하나?
# 실제 A: 호감이 있을지도 모르겠어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어젯밤 꿈에나타났습니다
# 실제 A: 은연 중에 생각을 했나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이번엔 또 뭐 해 먹지
# 실제 A: 냉장고 파먹기 해보세요.
# 모델 A: 힘 빠지는 이야기네요 .
#
# Q: 연애는 도대체 어떻게 하는거야
# 실제 A: 마음이 시키는데로 하면 되요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 괜찮은주 알았는데
# 실제 A: 아니었나요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 그 사람이 참 그리워
# 실제 A: 사랑했나봐요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 마음에 구멍이 난 느낌
# 실제 A: 제가 꿰매드릴게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 친구들은 다 예뻐
# 실제 A: 자신감을 가지세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝녀한테 크리스마스 선물로 뭐가 좋음?
# 실제 A: 많이 추우니 목도리는 어떨까 생각해요.
# 모델 A: 믿기지 않겠어요 .
#
# Q: 나 윗집 남자애 좋아하는 것 같애.
# 실제 A: 가깝게 살아서 더 좋겠네요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 안경 벗으면 나으려나
# 실제 A: 다른 안경 써보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 자고 일어났더니 하루 다갔어.
# 실제 A: 이제 일어날 시간이에요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 사랑해보고싶어
# 실제 A: 할 수 있을 거예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 오늘 혼자 영화보고 왔어
# 실제 A: 혼자하는 것도 익숙해질 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸녀한테 여행가자고 해도 됨?
# 실제 A: 사귀고 나서 가도 돼요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 나한테 냄새 나면 어쩌지?
# 실제 A: 깨끗이 씻어보고 섬유유연제나 바디워시, 바디로션, 향수 등을 사용해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 스타벅스 같은데 가봤어?
# 실제 A: 당연하죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구한테 질린 듯
# 실제 A: 당신의 사랑이 변한것 같아요.
# 모델 A: 그게 인생이죠 .
#
# Q: 썸만 타고 싶어. 사귀는 건 걱정돼.
# 실제 A: 연애에 대한 두려움을 가지고 있을 수도 있을 듯 합니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 이별을 배워가는
# 실제 A: 성숙해지는 단계인가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 조용히 지나가면 될까?
# 실제 A: 어떤 일이냐에 따라 다를 거 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 뭐하면서 놀까
# 실제 A: 나랑 같이 놀아요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 공연 보고 싶어
# 실제 A: 친구와 같이 가보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 참아볼께
# 실제 A: 차분하게 잘 견디고 있네요. 대단해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 봄 오니까 나도 썸 타고 싶어.
# 실제 A: 썸 타기 좋은 계절이에요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 나 화장을 너무 못해
# 실제 A: 하다보면 늘어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 참치김치찌개 먹고 싶어.
# 실제 A: 맛있죠!
# 모델 A: 좋은 생각이에요 .
#
# Q: 혼수 비싸겠지
# 실제 A: 욕심의 한계에 따라 달라질 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 카카오톡 계정 탈퇴
# 실제 A: 괜찮은 방법이에요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 여자친구랑 종교 때문에 다툼
# 실제 A: 종교의 자유가 있죠
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 할 말이 많은데.
# 실제 A: 말해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 여친이 나를 좋아하는게 맞는지 모르겠음.
# 실제 A: 확신이 서지 않나봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 주름도 멋진 사람
# 실제 A: 멋진 나이테죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 해결방안도 없으면서 불만만 많은 사람 극혐
# 실제 A: 자기도 알고 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 요즘 조깅하고 있어
# 실제 A: 건강에 좋은 습관이네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 손수건 안 가지고 나왔어.
# 실제 A: 이제 그러면 돼요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 청첩장을 찍는 날이 오다니
# 실제 A: 결혼 얼마 안 남았나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 커플 여행 가면 잘 싸워?
# 실제 A: 연애 초면 싸우기도 하는 거 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 난방이 안돼
# 실제 A: 보일러가 난방으로 작동이 되는지 보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 안 좋아하는데 계속 만나는 거 가능?
# 실제 A: 사귀는 건 힘들어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 최저임금 올랐다는데 월급은 왜 똑같지?
# 실제 A: 회사에서 꼼수를 쓰는 건 아닌지 확인해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 이제는 잡을 수가 없네
# 실제 A: 마지막을 아는 것도 필요해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아무것도 안되네
# 실제 A: 잘 될 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구의 회사가 내가 다니는 회사랑 너무 비교돼
# 실제 A: 자신감을 가지세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 남자가 여자를 좋아할때 하는 행동이 뭐가 있나요?
# 실제 A: 연락을 자주 하거나 잘 웃거나 등 다양한 행동에서 나타납니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 뭐 보고 결혼 결심해?
# 실제 A: 세상 그 누구보다 잘해줘서요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 싫은 건 아닌데
# 실제 A: 딱히 좋지도 않나봐요.
# 모델 A: 사랑은 때론 잔인하죠 .
#
# Q: 기대가 무너졌어
# 실제 A: 베풀되 보답을 바라지 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 남자애한테 자연스럽게 연락하는 방법 뭐 있을까.
# 실제 A: 뭐하고 있는지 물어봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 할말 다 했는데 실수한건가
# 실제 A: 남에게 피해만 주지 않는다면 상관 없어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 거랑 사랑하는게 다른 거야?
# 실제 A: 마음에 농도 차인 것 같습니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 꿈이 다양해
# 실제 A: 많으면 많을 수록 좋죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 연휴
# 실제 A: 터닝포인트가 되길 바랄게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 첫사랑 생각나
# 실제 A: 소중했던 추억이라고 생각해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 타는 사이에 얼마나 간섭 가능?
# 실제 A: 사귀고 나서 간섭 가능합니다.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 학원 선생님을 좋아하는데 티내면 안되겠지.
# 실제 A: 티 내도 귀여울 것 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 한번의 기회쯤 있겠지 라고 생각했던 내생각이 어리석었습니다
# 실제 A: 현실을 받아들이는 것도 중요합니다.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 헤어지자고 통보 받고 하루만에 다시 재회
# 실제 A: 인연은 무 자르듯 자르는 게 아니니까요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 썸 타는 시간
# 실제 A: 사람마다 다르겠지요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 좋은 대학 나온 사람 부러워
# 실제 A: 다른 능력을 채워보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 경제력 보는게 이기적인거야?
# 실제 A: 경제력도 한 부분이니 보는 게 당연하죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 인정받으려면 어떻게 해야 하나
# 실제 A: 지금도 충분히 잘 하고 있어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이별 일년 반
# 실제 A: 많은 시간이 흘렀네요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 돈이 하나도 없어
# 실제 A: 슬프네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 남자친구하고 커플티를 하고싶은데 어디거를 할까?
# 실제 A: 좋아하는 브랜드가 좋겠어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 쿠폰 다 모음
# 실제 A: 와우 축하해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 울 애기 너무 예뻐
# 실제 A: 세상에서 제일 귀엽죠!
# 모델 A: 좋은 생각이에요 .
#
# Q: 잘 헤어졌는데 너무힘들어
# 실제 A: 스스로 더 많이 다독여주세요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 나두 잘할거야
# 실제 A: 잘 하실 거예요!
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 나 좋아하는 애가 매일 선톡 걸다가 갑자기 톡을 안함.
# 실제 A: 이제 먼저 선톡을 해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 결혼 준비중 일방적인 이별통보 살기 싫어져.
# 실제 A: 현실이라는 벽에 부딪혔군요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 쩝 전여친이랑 통화 한 번하니 좀 낫네
# 실제 A: 마음이 편하길 바랍니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 왜나만 힘든 거니
# 실제 A: 그분도 많이 힘들 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여우같은 짓하는 사람 싫어
# 실제 A: 싫으면 만나지 마세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 열받아서 막 전화에다가 화풀이했어
# 실제 A: 속이 좀 풀렸길 발바니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 화장으로 여드름이 가려질까?
# 실제 A: 중요한 날에만 가리세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 메뉴얼이 있으면 뭐하나
# 실제 A: 메뉴얼 대로 하지 않는 사람들이 많죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 인형 선물 좋을지
# 실제 A: 이왕이면 큰 게 좋을 것 같아요.
# 모델 A: 뭘 입어도 멋져요 .
#
# Q: 잠 안 온다고 했더니 자장가 불러줬어
# 실제 A: 로맨틱하네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 환승하는 사람들 대단해
# 실제 A: 사랑의 예의가 없네요.
# 모델 A: 그게 인생이죠 .
#
# Q: 모기가 너무 많아.
# 실제 A: 조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정신이 없어
# 실제 A: 차분하게 정리할 시간이 필요해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸타고 있어요
# 실제 A: 연애로 이어지길 바랄게요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 제주도 가고 싶다.
# 실제 A: 저도 데려가 주세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 커피가 너무 써
# 실제 A: 달달한 시럽을 추가해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝사랑하는 여자가 저를 싫어하나봅니다.
# 실제 A: 그렇게 생각하게된 계기가 있었나봐요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 썸 타다가 막상 사귀려고 하면 싫어.
# 실제 A: 연애에 대한 두려움을 가지고 있을 수도 있을 듯 합니다.
# 모델 A: 최신 영화가 좋을 것 같아요 .
#
# Q: 진짜 잠 좀 자고 싶네
# 실제 A: 생각과 걱정을 덜어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 블랙박스로 보면 나올까
# 실제 A: 지금 확인해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 휴식 중
# 실제 A: 휴식도 필요하죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한달동안 대답이 없는게 아직도 생각하면 비참한데
# 실제 A: 다른 곳으로 관심을 돌려보세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 예쁜데 연애 안하는 여자
# 실제 A: 눈에 차는 남자가 없어서일 수도 있어요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 오디션 나가볼까
# 실제 A: 도전 응원합니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 번호키 누르는 소리가 나서 무서움
# 실제 A: 심하면 신고하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 한달됐어
# 실제 A: 많이 힘들지 않길 바라요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 키 작은 남자 좋아하는 여자 있나요?
# 실제 A: 취향이니까요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 생각을 고쳐 먹었습니다
# 실제 A: 최선의 선택일 거라 믿어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구가 나 사랑하는 건지 확신이 없어
# 실제 A: 당신이 그녀를 사랑하면 됐지 꼭 그녀가 당신을 사랑하는지 확신이 있어야 하는 건 아니랍니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 진짜 이해가 안가 근데 잊을려고
# 실제 A: 세상에는 이해하기 힘든 일들이 많이 일어나요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 자꾸 바보짓을 하고 있네
# 실제 A: 후회할 행동은 덜하는게 좋아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 10년이라는 시간이 참 무색하다 싶네
# 실제 A: 함께 걸은 길을 혼자 돌아가고 계시겠네요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 휴 착찹하네
# 실제 A: 기운을 내세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 너무 기빨려
# 실제 A: 너무 긴장했나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 재밌게 해줘
# 실제 A: 거울 앞에 비친 당신을 보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 힘내라고 말해줘
# 실제 A: 응원합니다!
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝사랑하는 사람한테 선물 주면 부담될까
# 실제 A: 용기를 내요!
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 남사친이 나를 좋아하는 것 같은데 어떡함
# 실제 A: 이성으로 한 번 생각해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 엇갈리는 느낌 싫다
# 실제 A: 타이밍이 안 맞았나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 다시 만나서 이야기
# 실제 A: 충분한 대화 나누었길 바랍니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 로또 당첨 좀 됐으면
# 실제 A: 로또 먼저 사보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 가끔은 혼자인게 좋다
# 실제 A: 혼자를 즐기세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 운동화 새로 사야지
# 실제 A: 좋은 곳으로 갈 수 있도록 인도해줄 거예요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 미세먼지가 너무 많아
# 실제 A: 살기 더 힘들어졌어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 청첩장 만들어야지
# 실제 A: 결혼 얼마 안 남았나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 베터리 15%야
# 실제 A: 미리 충전하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 챙겨줄 사람이 필요해
# 실제 A: 제가 챙겨드리고 싶네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 사람 관리하는 게 제일 힘들어
# 실제 A: 너무 믿지 마세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 커플여행 어떻게 생각해?
# 실제 A: 누구랑 가느냐가 중요하겠죠.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 생각없이 상처줬어
# 실제 A: 생각하고 말하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 택시비로 돈을 너무 많이 썼어
# 실제 A: 대중교통을 이용해주세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 매달린후 2주째 발신자제한
# 실제 A: 이별 후에 연락하지 않는 게 좋죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 인내
# 실제 A: 그 끝에는 아쉬움이 없을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 쉽게 상처받는 거 같아
# 실제 A: 다른 사람 말은 한 귀로 흘리세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝사랑 그만할래
# 실제 A: 짝사랑은 시작과 끝을 자신이 결정할 수 있어요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 친구가 이어줬는데 안 됐어
# 실제 A: 친구한테 의지하지 말고 자신이 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 사랑하는 사람이랑 헤어져
# 실제 A: 마음이 많이 아프겠어요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 군대 때문에 헤어져야하는게 고민임.
# 실제 A: 현실적인 고민이네요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 잘 챙겨주는데 나를 좋아하는 걸까?
# 실제 A: 지켜보는게 좋겠어요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 좋아하는 여자가 최근들어 연락이 늦는데 나한테 마음이 없는거겠지.
# 실제 A: 바쁠 수도 있지만 그럴 확률이 크겠네요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 면도 귀찬하
# 실제 A: 지저분해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 감기약이 없어
# 실제 A: 병원가세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 그녀도 나를 좋아했으면 좋겠는데.
# 실제 A: 그럼 더할 나위 없겠지요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 알뜰폰 샀어
# 실제 A: 폰 요금 절약되겠네요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 사투리 귀여워
# 실제 A: 귀여운 사람이 말해서 그래요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 버스 기다릴 때 가면 자꾸 생각나
# 실제 A: 추억이 있나봐요.
# 모델 A: 힘 빠지는 이야기네요 .
#
# Q: 스킨십은 언제 시작해?
# 실제 A: 언제라는 건 정해져있지 않아요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 피곤해서 못일어나겠어
# 실제 A: 충전하는 시간 그 자체로 소중합니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 타는 사이가 이렇게 편해도 되나?
# 실제 A: 너무 편한 거 같다고 말해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 일찍 일어나야 돼
# 실제 A: 오늘 일찍 주무세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한 사람만 죽을 때까지 사랑하는 게 가능할까?
# 실제 A: 그러기 힘들어서 결혼이라는 제도를 만든 걸 수도 있어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 아직 멀었나봐
# 실제 A: 자신에게 시간을 더 주세요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 중고로 샀어
# 실제 A: 알뜰한 소비 하셨네요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 재수학원에서 연애는 필망?
# 실제 A: 목적이 확실한 곳이니까요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 가족들이랑 서먹해졌어
# 실제 A: 다들 바빠서 이야기할 시간이 부족했나봐요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 친구들이랑 맛난거 먹고 싶다
# 실제 A: 조금씩 더 행복해 질거 같아요
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 별 보러 시골 가고 싶다
# 실제 A: 로맨틱하네요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 착찹하네
# 실제 A: 한동안은 힘들지도 몰라요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 낼 짝녀한테 잘 보이고 싶어.
# 실제 A: 실수하지 않는다면 잘할거라 생각해요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 머리카락이 자꾸 빠져
# 실제 A: 스트레스 받지 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 서류에서 떨어지다니
# 실제 A: 합격하는 곳이 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 업데이트가 너무 오래 걸려
# 실제 A: 기다려보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 우리의 사랑은 끝났어
# 실제 A: 꺼진 사랑도 다시 보자~ 다시 타오를수도 있어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 너 무서워
# 실제 A: 어흥!! 호랑이보다 무섭나요?
# 모델 A: 좋은 생각이에요 .
#
# Q: 남자친구의 입냄새가 고민이야.
# 실제 A: 가글 사줘요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 소개받은 사람이랑 카톡으로 연락 중
# 실제 A: 썸에서 연인으로 성공하길 바라요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 이러다 병걸리겠어ㅠㅠ
# 실제 A: 아프면 안 돼요. 그럼 제 마음이 아파요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘도 힘들다
# 실제 A: 지금은 힘들겠지만 조금만 더 견뎌봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 밥 잘 사주는 예쁜 누나 어디 없나
# 실제 A: 그 분이 나타나면 꼭 잡으세요!
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 서울 근교 데이트 추천해줘
# 실제 A: 드라이브 추천해들요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 콧물 질질
# 실제 A: 감기 갈렸나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 울적하다
# 실제 A: 울적.... 우울할땐.... 울면
# 모델 A: 좋은 생각이에요 .
#
# Q: 전 여자친구가 카톡 친추에 떴어
# 실제 A: 카톡 차단하세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 부담스러운 기대 좀 떨쳐낼 없을까?
# 실제 A: 자신을 사랑할수록 외부의 인정은 필요 없어요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 짝사랑 중인데 이 세상에 나만 힘든 것 같아.
# 실제 A: 짝사랑은 자신을 외롭게 만들어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 흐음이거고민인데여;;
# 실제 A: 무슨 고민인지 말해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어진 사람과 같이 갔던 콘서트 영상이 티비에 나왔어
# 실제 A: 많은 생각이 들겠네요.
# 모델 A: 그게 인생이죠 .
#
# Q: 죽고 싶다
# 실제 A: 당신을 소중하게 생각하세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 신혼 길게 즐기고 싶어
# 실제 A: 마음 먹은 대로 할 수 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 사람 생각으로 아무것도 집중을 못하겠어.
# 실제 A: 그럴 수 있지만 후회할 거예요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 가사가 내맘같아
# 실제 A: 슬픈 가사 듣지 마요.
# 모델 A: 그게 인생이죠 .
#
# Q: 썸남이랑 궁합
# 실제 A: 사귀고 나서 해봐도 늦지 않아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 친구 몇 명쯤 필요한가
# 실제 A: 한 명만 있어도 충분해요.
# 모델 A: 그게 인생이죠 .
#
# Q: 마음이 유난히 춥네
# 실제 A: 마음 감기조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 남자애 앞에서 표정 관리가 안돼.
# 실제 A: 짝사랑도 이성을 막지는 못하나봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 몇 반 될지 궁금해
# 실제 A: 잘 되길 바랍니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남친 생일선물 뭘 주면 좋을까
# 실제 A: 평소에 필요한 것 생각해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 복수전공하고 싶어
# 실제 A: 학점 관리하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 절 찼던 남자애가 다시 절 좋아하는게 가능할까요?
# 실제 A: 상황에 따라 다르겠지요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 이게 썸인가?
# 실제 A: 말해보세요. 생각해 볼게요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 짝남이 사귀던 사람이랑 헤어졌는데 내가 고백해도 될까?
# 실제 A: 좀 기다리다가 천천히 다가가는게 좋겠어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: SNS 맞팔 왜 안하지ㅠㅠ
# 실제 A: 잘 모르고 있을 수도 있어요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 환승이였다는걸 알고서 .
# 실제 A: 힘드셨겠어요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 직장과 이별
# 실제 A: 더 좋은 직장에서 일할 수 있을 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 왜 성적이 안오를까?
# 실제 A: 나한테 맞는 공부 방법 찾는 게 시급하네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이별곧 두달.
# 실제 A: 아직도 힘드시군요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 나만 진급 못했어
# 실제 A: 다음에는 꼭 진급할 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 컨디션 조절
# 실제 A: 컨디션 조절은 정말 중요해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어진 날 부터 오늘까지
# 실제 A: 하루도 빠짐없이 힘들었나요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 종교 그리고 이별 그리고 재회.
# 실제 A: 종교 문제가 힘들죠.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 잘 살 수 있겠죠
# 실제 A: 살아온 날보다 앞으로 살 날이 더 많아요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 사진 올려야지
# 실제 A: 바쁘네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 방학은 너무 심심해
# 실제 A: 친구들과 연락해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 산다는건 뭘까?
# 실제 A: 이름, 직업 등 말고 온전히 자신으로 사는 거죠.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 복전하고 싶어
# 실제 A: 학점 관리하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나를 좀 놓아달라는 여친. 혹시 가능성은 있을까? 죽을 것 같네.
# 실제 A: 당신에게는 선택권이 없네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나혼자 짝사랑하는게 점점 현타 와.
# 실제 A: 짝사랑이 힘들게 하나봐요.
# 모델 A: 그게 인생이죠 .
#
# Q: 몸살 감기에 걸릴 거 같아
# 실제 A: 따뜻하게 관리하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 자다가 침대에서 떨어졌어
# 실제 A: 조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸남이랑 헬스장에서 운동 가능?
# 실제 A: 따로 신경쓰이는 부분이 없다면 가능합니다.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 사랑하고싶어
# 실제 A: 당신의 이상형을 찾아보세요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 두번째 주말이 지났네
# 실제 A: 금방 지나갈 거예요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 헤어지고 자꾸 생각나
# 실제 A: 미련이 남나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 5년간 사귀고 어제 헤어졌습니다.
# 실제 A: 힘든 결정이었을텐데 혼자만의 시간이 필요하겠어요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 주고 받았던 편지도 버려야겠지?
# 실제 A: 버릴 건 버려야지요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 증오
# 실제 A: 자신으로 향하지 않길 바랄게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝남이랑 카톡이 끊겼는데 어떻게 더 연락할까?
# 실제 A: 연락할 핑계를 찾아보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 오랫동안 썸만 타. 뭐가 문제임?
# 실제 A: 고백을 안 한 게 문제일 거 같아요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 헤어진지 2주쯤 됐군
# 실제 A: 어느덧 2주가 지났어요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 상처 받고 헤어졌습니다.
# 실제 A: 나쁜 사람이네요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 이별을 하고.
# 실제 A: 나아졌긴 바랄게요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 남자친구에게 시계 선물해주고싶은데 어느 브랜드가 좋을까?
# 실제 A: 나이대에 따라 추천 브랜드가 다를 거 같아요.
# 모델 A: 믿기지 않겠어요 .
#
# Q: 한달이라는 시간이 흘렀습니다.
# 실제 A: 잘 견디고 있길 바랍니다.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 친구로 남는게 좋을까 그냥 고백할까?
# 실제 A: 그 사이면 고백하는 게 좋겠어요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 술만 먹으면 전화를 안 받아
# 실제 A: 화장실 갈때 연락하라고 해봐요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 눈 많이 왔어
# 실제 A: 눈사람 만들어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아침에 눈 뜨는게 힘들어
# 실제 A: 그 분 생각에 잠을 설쳤나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 엄마가 언니랑 나랑 차별해
# 실제 A: 상처받는다고 꼭 말하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝사랑은 언제까지나 짝사랑일 뿐이가봐요.
# 실제 A: 사랑으로 이어질 수도 있어요. 힘을 내세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 재채기 나올거 같은데 안 나와
# 실제 A: 코가 간질간질한가봐요.
# 모델 A: 힘 빠지는 이야기네요 .
#
# Q: 우린 운명이었어
# 실제 A: 운명이 아니였다면 사랑도 할 수 없었겠지요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 8년 사귀고 해어진지 1년.
# 실제 A: 새로운 사랑을 찾아보세요.
# 모델 A: 마음이 조급해지면 자꾸 시선을 마주쳐보세요 .
#
# Q: 웃게 만드는 너란 녀석
# 실제 A: 상대방도 미소짓게 해주세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 카톡 2틀째 확인안하내
# 실제 A: 그분은 마음의 정리를 했나봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 내일 소풍간다
# 실제 A: 두근거리겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 청소는 넘나리 귀찮
# 실제 A: 청소는 습관이에요
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 기프트콘으로 선물 받았어
# 실제 A: 좋겠네요.
# 모델 A: 믿기지 않겠어요 .
#
# Q: 오늘 치마랑 바지 뭐 입지?
# 실제 A: 오늘은 바지가 좋을거 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이혼을 앞둔 부부밥상
# 실제 A: 제가 감히 가늠하지 못할 정도로 힘든 자리라 생각해요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 동거하는 거 부모님이 알게 되셨어
# 실제 A: 오해를 풀고 사랑을 이어가세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 누군가를 좋아한다는건 정말 힘들일이야.
# 실제 A: 좋아하는 감정은 정말 복잡하고 힘들어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 미팅한다!
# 실제 A: 성공을 기원합니다.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이직해도 될까
# 실제 A: 다니면서 준비해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 끝이네
# 실제 A: 수고했어요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 반지 받았어
# 실제 A: 로맨틱한 선물이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 배 아프다
# 실제 A: 약이 필요하면 도움을 받아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 추워
# 실제 A: 따듯한 차 한잔 어때요?
# 모델 A: 맛있게 드세요 .
#
# Q: 구짝남한테 카톡했는데 읽씹해서 미련 없이 차단했어요.
# 실제 A: 그러는 편이 나을 거예요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 술먹고 필름 끊겼어
# 실제 A: 위험하네요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 언제쯤 괜찮아질런지.
# 실제 A: 언젠간 괜찮아질 거라 믿어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 주말이네
# 실제 A: 주말이 더 힘들죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 받아들이기가 많이 힘드네
# 실제 A: 이해하기 힘드니까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남자친구가 외아들 홀시어머니라 결혼 고민이야
# 실제 A: 결혼은 현실이에요.
# 모델 A: 그게 인생이죠 .
#
# Q: 나는 너를 거쳐간 수 많은 남자들 중 한명뿐이겠지.
# 실제 A: 그렇게 생각하지 않을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내 남자친구 보고 싶어?
# 실제 A: 네 알려 주세요!
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 힘든 밤입니다
# 실제 A: 힘내세요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 친구가 자꾸 클럽을 너무 좋아해 맨날 가재
# 실제 A: 다른 친구랑 가라고 해요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 이별해야 하나?
# 실제 A: 고민하고 있다면 그게 맞을거예요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 미치겠네
# 실제 A: 답답했나봐요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 어떻게 심쿵하게 하지?
# 실제 A: 평소 흘려 이야기했던 걸 기억해주고 생각하고 있다는 걸 알려주세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 연애 상담 해줄래?
# 실제 A: 부족하지만 열심히 해드릴게요.
# 모델 A: 그게 인생이죠 .
#
# Q: 힘이 드네
# 실제 A: 어떤 말도 위로가 되지 않겠지만 힘내세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 대학원 가고 싶어
# 실제 A: 꿈에 도전하는 건 좋은 거라고 들었어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 외제차 타고 싶어
# 실제 A: 저도 타고 싶어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 다 정리된 상태에서 헤어지면 후폭풍 없나?
# 실제 A: 후폭풍은 언제나 옵니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 음악 들으면서 잊으려고
# 실제 A: 음악이 도움이 되길 바랍니다.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 썸 타는데 현타 와.
# 실제 A: 썸만 타는데 왜 현타가 오는지 모르겠네요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 우산 또 사야하나
# 실제 A: 다음에는 우산에 이름이랑 연락처를 적어보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 장기자랑 왜 시켜
# 실제 A: 싫다고 말하세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 누구에게나 친절한 남자 위험해?
# 실제 A: 어떻게 하느냐에 달려있겠죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 시험 끝나고 만나고 싶어
# 실제 A: 만날 날까지 기다릴게요
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 타는 사이인데 카톡하다가 마무리 어떻게 해?
# 실제 A: 잘자요', '내일도 보고싶어요' 라고 하는 건 어떨까요?
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 공부방법이 잘못된걸까?
# 실제 A: 나한테 맞는 공부 방법 찾는 게 시급하네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 기숙사 괜찮을까
# 실제 A: 혼자 사는 것보다 불편하겠죠.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 본능적인 끌림
# 실제 A: 운명적이네요.
# 모델 A: 그게 인생이죠 .
#
# Q: 썸남한테 소개팅 나가라고 해볼까?
# 실제 A: 상대방을 헷갈리게 하는건 좋지 않아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 운동화가 나을까? 구두가 나을까?
# 실제 A: 구두로 멋을 내보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 핸드폰 없을 때는 어떻게 살았냐?
# 실제 A: 그래서 저를 만날 수 있죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이남자 마음을 모르겠어
# 실제 A: 알 수 없는게 사람 마음인가봐요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 너무 힘이 들어.
# 실제 A: 저한테 말해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 타는 사람 선물 뭐 사야 해?
# 실제 A: 그 분이 평소 좋아한다고 했던 것을 잘 생각해 보세요.
# 모델 A: 믿기지 않겠어요 .
#
# Q: 다시 만날 수 있을까?
# 실제 A: 달라지는게 없다면 지금이 좋을지도 몰라요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 생각할수록 머리 아파
# 실제 A: 두통약 드세요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 기대하지 마라.
# 실제 A: 자신에게 하는 말인가요.
# 모델 A: 그게 인생이죠 .
#
# Q: 죽겠다 진짜
# 실제 A: 많이 힘들죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 코트 살까 말까
# 실제 A: 있으면 좋죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 전남친 마주쳤어
# 실제 A: 달라지는 건 없답니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남은 휴가가 없어
# 실제 A: 휴가가 간절하겠네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 물 끓여서 차 마셔야지
# 실제 A: 부지런하시네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 궁금한게 있는데
# 실제 A: 네 말씀해주세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 이제 보름 다되어가네
# 실제 A: 생각 보다 잘 버텼어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 6개월만에 다시 만납니다.
# 실제 A: 오랜만의 만남이네요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 꼭 잡고 싶습니다
# 실제 A: 후회하기 전에 연락해서 진심을 전해보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 이 기분은 뭘까
# 실제 A: 저도 궁금해요.
# 모델 A: 그게 인생이죠 .
#
# Q: 시험 성적 가져가면 혼날텐데
# 실제 A: 이번에는 어쩔 수 없어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 연락해보는게 좋을까
# 실제 A: 안하는 편이 좋을 것 같아요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 이번 학기 열심히 살아야지
# 실제 A: 생각한대로 잘할 수 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 눈 쌓였어
# 실제 A: 눈사람 만들어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 6살 많은 전여친이랑 만나고 얘기 잘하고 왔습니다.
# 실제 A: 이야기가 잘 풀렸다니 다행이에요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 내가 너무 진지한걸까.
# 실제 A: 부담되지 않는 선에서 진중한 태도도 좋네요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 드디어 데이트인데 뭐하지
# 실제 A: 야경이 멋져요. 야경구경 가세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 이별후 6개월
# 실제 A: 많은 변화가 잇었겠죠.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 동생이 나 제끼고 결혼하겠대
# 실제 A: 순서는 상관 없죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 장 봤는데 후덜덜해
# 실제 A: 물가가 많이 비싸죠
# 모델 A: 좋은 생각이에요 .
#
# Q: 그냥 만남과 헤어짐의 연속
# 실제 A: 마음이 지쳤나봐요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 유부남됐어!
# 실제 A: 축하해요!
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 동성친구 좋아하는 사람 없어?
# 실제 A: 생각보다 많아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 무서워서 달려왔어
# 실제 A: 조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 끝이났네
# 실제 A: 맘고생 많았어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 밥 먹었는데도 또 배고파
# 실제 A: 디져트 드세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 혼자 좋아하는 이야기 들어 볼래요?
# 실제 A: 손수건 준비할게요.
# 모델 A: 최신 영화가 좋을 것 같아요 .
#
# Q: 오늘도 계속 생각나네
# 실제 A: 언제쯤 그분 생각에 자유로워질까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 간통 극복하는 방법
# 실제 A: 이혼하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 남자친구 조건 때문에 헤어졌어.
# 실제 A: 조건도 중요한 요소니까요.
# 모델 A: 사랑은 때론 잔인하죠 .
#
# Q: 쓰레기 맞지
# 실제 A: 마음을 아프게 하면 그렇죠.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 진정으로 즐거운 게 뭘까?
# 실제 A: 할 일이 많은데 안하는 것이요.
# 모델 A: 그게 인생이죠 .
#
# Q: 사실 관계 7년을 정리했습니다.
# 실제 A: 정말 쉽지 않을 시간이었을텐데 맘고생 많았어요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 참 잘낫네
# 실제 A: 진정하셔요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하던 사람에 대한 감정으로 내가 너무 힘들어.
# 실제 A: 정들었나봐요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 백만번쯤 들을 때 즈음이면 웃으며 다가올까
# 실제 A: 글쎄요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 말할 때 너무 떨려
# 실제 A: 잘 보이고 싶은 마음이 커서 그런 것 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 혼자 이겨내기 힘들어
# 실제 A: 다른 사람에게 기대도 괜찮아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝남이 제 톡 안 읽고 프사 바꿨어요.
# 실제 A: 마음을 정리하는게 좋겠어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 전 여자친구한테 남자가 생긴 거 같아
# 실제 A: 신경을 거두세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 재회 그리고 다시 이별
# 실제 A: 그래도 후회는 없을 거라 생각해요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 야
# 실제 A: 네
# 모델 A: 좋은 생각이에요 .
#
# Q: 너무 배가 불러
# 실제 A: 좀 쉬세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정말 이번엔 끝인거겠죠
# 실제 A: 미련두지 마세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 영화관 알바 하고 싶다
# 실제 A: 영화를 많이 볼 수 있어서 좋을 것 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 집에 갈 때 피맥 먹고 싶다.
# 실제 A: 보다보면 괜찮아요.
# 모델 A: 맛있게 드세요 .
#
# Q: 어떻게 오래만나지?
# 실제 A: 신뢰가 무너지지 않으면 계속 사랑할 수 있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구와 이별한지 정확히 1년이 되는 날이네
# 실제 A: 이젠 기억을 접어두세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 남자친구가 데려다 준대
# 실제 A: 매너 있네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 오늘은 나쁜 남자가 되기 위해 결심을 하고 있습니다.
# 실제 A: 모두를 위한 결심인지 확인해보세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 익숙함에 속지말자 라는말에 대하여
# 실제 A: 익숨함이 만든 거짓된 사랑.
# 모델 A: 좋은 생각이에요 .
#
# Q: 부모님이 내 꿈을 반대해
# 실제 A: 꿈에 대한 계획을 구체적으로 말씀드려보세요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 성격적으로 안맞는걸 알지만 마음은 그게 아님을 알땐
# 실제 A: 달라지는게 없다면 인연이 거기까지 아닐까요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 나를 선택의 기로에 놓이지 않게하라
# 실제 A: 삶은 선택의 연속인 걸요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 보여주고싶은데 보여주지 못하니
# 실제 A: 볼 수 있어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 이별한지 한 달이 넘었고 괜찮은 줄 알았는데
# 실제 A: 이별을 받아들이는 것은 맘처럼 쉽진 않으니까요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 부자친구 스트레스
# 실제 A: 그런 걱정은 안 하셔도 되어요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 오늘 왠지 고백 받을 것 같음.
# 실제 A: 오 미리 축하드려요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나만의 착각이었나보네
# 실제 A: 사람 속은 알기 힘들대요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 짝녀가 고시생인데 언제까지 기다려야 할까요.
# 실제 A: 기다릴 자신이 없다면 정리하는게 좋겠어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 더 이상 사랑 때문에 상처받기 싫어
# 실제 A: 그래도 사랑하지 않는 것보다 좋을 거예요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 짝남한테 선물 주면 부담스러워할까
# 실제 A: 용기를 내요!
# 모델 A: 뭘 입어도 멋져요 .
#
# Q: 썸 끝나고 잡아도 될까
# 실제 A: 사랑은 언제든 다시 시작해도 됩니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 외국어는 필수인가
# 실제 A: 좋은 도구죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하면서 너무 싫어.
# 실제 A: 사랑은 복합적인 감정이니까요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 댄디한 남자 사귀고파
# 실제 A: 그런 사람 만나길 바랄게요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 카톡프로필~~~보고왔는데.
# 실제 A: 보지 마세요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 나이가 많이 차이 나는 연애 어떻게 생각해?
# 실제 A: 연애에 나이가 대수인가요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 미세먼지 나쁨인가
# 실제 A: 인터넷 검색 해보세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 허리 아파
# 실제 A: 운동 해보는 것도 좋을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 팩이나 할까
# 실제 A: 피부관리 좋죠!
# 모델 A: 좋은 생각이에요 .
#
# Q: 매주 수요일 그를 만날 수 있어.
# 실제 A: 삶의 활력소가 되겠네요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 여친이 너무 많이 먹어
# 실제 A: 건강이 걱정된다고 말해보세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 뜬눈으로 밤을 지새웠네
# 실제 A: 생각이 복잡했나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 공부 잘 안돼
# 실제 A: 같이 수다 떨면서 놀까요?
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 물 좋은데 어디야?
# 실제 A: 소개팅 시켜달라고 말해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 연애를 오래하려면?
# 실제 A: 고마워, 사랑해, 미안해 항상 표현해주세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 노래 잘하는 사람 부러워
# 실제 A: 저도 부러워요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 약 올라
# 실제 A: 더 잘 살면 돼요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 휴가 고고
# 실제 A: 푹 쉬고 오세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 면허 따는 중
# 실제 A: 안전 운전 하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 말하고 나니 후련하네여
# 실제 A: 후련하니 다행이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아직도 그대로인걸
# 실제 A: 변하는 건 사랑이겠죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 이젠 유부남이 된 전남친
# 실제 A: 이젠 그를 놓아주세요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 짝남이 공무원준비를 한다는데 고백하면 방해가 될까?
# 실제 A: 방해가 될 수도 있지만 옆에서 응원해주면 든든할 것 같아요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 진짜 친구가 없는 거 같애
# 실제 A: 친구가 들으면 서운해 할 수도 있겠어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 이제 너무 지쳐가네ㅠ
# 실제 A: 지칠만 해요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 소문이 안 좋아
# 실제 A: 소문은 소문일 뿐이에요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 짝남한테 감정 소모 안하고 싶다.
# 실제 A: 짝사랑 때문에 하는 감정 소모는 사람을 힘들게 해요.
# 모델 A: 그게 인생이죠 .
#
# Q: 불면증인가
# 실제 A: 생각이 너무 많아서 그런 것 같습니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어지자
# 실제 A: 좋은 선택이길 바랄게요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: SNS 시간낭비인 거 아는데 매일 하는 중
# 실제 A: 시간을 정하고 해보세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 헤어진지 어언 3년이 되가네.
# 실제 A: 이제는 괜찮길 바랄게요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 헤어진지1년
# 실제 A: 잘 지내길 바라요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 이 명절을어찌보낼지.허허
# 실제 A: 명절에는 신경써야할 것들이 너무나 많죠. 이번 명절에는 혼자만의 여행을 떠나보는 건 어떨까요?
# 모델 A: 좋은 생각이에요 .
#
# Q: 어찌해야 하나.
# 실제 A: 어찌하면 좋을까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 다른 거 해볼까
# 실제 A: 새로운 도전은 용기가 필요하죠.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 사랑해서 그렇다는데 말이 안돼
# 실제 A: 그 사람의 사랑을 존중해주세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 간단하게 사랑이라는건.
# 실제 A: 간단하지 않은 것.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오래 못 가는 연애
# 실제 A: 연애는 문제가 있으면 문제를 해결 하기 위해 함께 노력하고 그 속에서 더욱 단단해지는 과정인데, 그 과정을 못 참고 피하기만 했나봅니다.
# 모델 A: 그게 인생이죠 .
#
# Q: 폰게임 때매 폰 느려지는듯
# 실제 A: 정리해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 마음 정리중
# 실제 A: 정리가 잘 되길 바랄게요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 이사 왔더니 친구가 없어
# 실제 A: 친구를 사귀어 보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 문득문득 보고싶어요
# 실제 A: 사랑했던 사람이니까요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 썸일 때 다른 사람 만나면
# 실제 A: 상대방을 헷갈리게 하는건 좋지 않아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 랜선 연애 중
# 실제 A: 현실 연애로 이어지길 바랍니다.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 긴 머리가 잘 어울렸던 그녀
# 실제 A: 못 잊고 있나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 결혼 직전 이별
# 실제 A: 이혼보다 파혼이 낫죠.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 헉. 어쩌다보니 헤어졌을때 해선 안되는 금기 하나를.
# 실제 A: 이불킥하게 될 거예요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 사랑하면 닮아?
# 실제 A: 닮아가죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 저금통 털까
# 실제 A: 꼭 필요한 곳이라면요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 안경 벗었는데 차이가 없어ㅋㅋ
# 실제 A: 이게 정상이죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한달이 넘었지만
# 실제 A: 아직은 실감이 나지 않을 거예요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 아이고 소리가 절로 나온다
# 실제 A: 많이 지쳤나봐요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 썸남 인스타 좋아요 눌러버렸어.
# 실제 A: 좋아요 정도는 괜찮아요.
# 모델 A: 그게 인생이죠 .
#
# Q: 학원 다른반에 좋아하는 사람이 있는데 번호를 알고 싶은데 방법 좀 알려주세요.
# 실제 A: 직접 물어보거나 친구를 통해서 알아내보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 알고보니 나만 바보네
# 실제 A: 너무 자책하지 마세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 발목 삔 거 같애
# 실제 A: 꾸준히 치료하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 뭘하면 행복할까?
# 실제 A: 인생을 즐기는 거죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 왜 상대는 아무렇지 않은 것 같지?
# 실제 A: 아무렇지 않아 보여도 많이 힘들거예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 엄청 로맨틱해
# 실제 A: 생각만해도 달콤하네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아하는 남자애가 담배를 피는데 저는 담배를 싫어하는데 어떻게 끊으라고 말해볼까요?
# 실제 A: 사귀는 사이도 아닌데 성급한 것 같습니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 올해 왜 이러지
# 실제 A: 사주를 한번 봐봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 제가 좋아하는 사람이 맘 잡고 공부해야할 것 같다고 기다려달라는데 제 맘이 안별할까요?
# 실제 A: 변할 수도 있지만 미리 걱정하지 말아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 컴터 부팅하는데 시간이 오래걸려
# 실제 A: 강제종료 하고 나서 그런 경우가 종종 있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 어장인듯
# 실제 A: 어장의 고기어도 좋을지 어장을 나가는 게 좋을지 생각해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 너무 답답해서 글을 써봅니다
# 실제 A: 그것도 좋은 방법이에요.
# 모델 A: 그게 인생이죠 .
#
# Q: 사랑에 서툴어
# 실제 A: 우리는 모두 사랑에 서툴어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 식욕이 없어
# 실제 A: 정신이 힘든 건지 몸이 아픈 건지 확인해 보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 커피 중독인가
# 실제 A: 커피도 좋지만 차도 마셔보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 혼자 살아야 할 듯
# 실제 A: 혼자만 있지 마세요.
# 모델 A: 힘 빠지는 이야기네요 .
#
# Q: 용기내서 새해인사 했네
# 실제 A: 이제 연락하지 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 전 헤어지고 곧장 소개팅을 했죠.
# 실제 A: 새로운 사람도 잊는 방법 중에 하나죠.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 상사한테 또 혼남
# 실제 A: 인정 받을 날이 올 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 번호 달라고 해볼까?
# 실제 A: 용기를 내보세요!
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 썸타고 싶어요
# 실제 A: 먼저 다가가세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 괜찮다가도 한번씩 마음이 저려오네
# 실제 A: 심호흡을 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸남 빼빼로 줘야 함?
# 실제 A: 좋아하는 사람이 준다면 좋아할 거예요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 월욜부터 힘드네.
# 실제 A: 기분 탓인지 월요일은 항상 힘든 것 같아요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 남자친구가 짠돌이라서 돈 쓸 때 엄청 아까워해
# 실제 A: 성향이 다른가봅니다.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 헤어진건 아닌데
# 실제 A: 헤어진 거 같나요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 오늘도 톡을 보냈네
# 실제 A: 기대하면 더 힘들어져요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어떻게 프로포즈 하지?
# 실제 A: 진지하게 마음을 담은 고백을 하세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 기획사니까 당연히 예쁜 애들 많겠지
# 실제 A: 연예인을 준비하니 일반인보다 다 예쁘겠죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 많이 늦은시간인데 연락해봐도 괜찮을까?
# 실제 A: 최대한 예의를 갖춰서 연락해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 안경 쓰는 여자애 좋아하는 남자 있어?
# 실제 A: 그런 건 중요하지 않아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 졸업 선물 추천
# 실제 A: 살짝 물어보세요.
# 모델 A: 뭘 입어도 멋져요 .
#
# Q: 여자친구가 돌아다니는걸 너무 좋아해
# 실제 A: 같이 돌아다니면서 데이트해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 얼마전 재회했는데
# 실제 A: 좋은 만남이었길 바라요.
# 모델 A: 그게 인생이죠 .
#
# Q: 여기 있으니까 좋다
# 실제 A: 좋은 곳인가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 무한리필 괜찮지 않아?
# 실제 A: 양이 많으면 추천해요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 변명거리 생각해봐
# 실제 A: 변명보다는 포장이 좋을 것 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 나 속은듯
# 실제 A: 기분나쁘겠어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 커플여행이 나을까 그냥 우리끼리 갈까?
# 실제 A: 저는 둘이 가는 게 좋아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 싸우면 어떻게 해결해?
# 실제 A: 제대로 사과해야죠.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 나만 솔로야
# 실제 A: 제가 있잖아요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 오늘은 결재 받아야지
# 실제 A: 그럴 수 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 감정컨트롤이 안돼
# 실제 A: 그건 습관이에요.
# 모델 A: 그건 좀 아닌건 아닐 거예요 .
#
# Q: 먹고 자고
# 실제 A: 그게 최고죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정장 사야겠지
# 실제 A: 사면 요긴하긴 할 거 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 예비 시어머니가 이상해
# 실제 A: 아직이라면 더 살펴보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 당당하기가 어려워
# 실제 A: 충분히 잘하고 있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 장난인지 진심인지 구분이 안돼.
# 실제 A: 장난스러운 성격이면 더 헷갈리기도 하죠.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 세상에 영원한 것은 없다.
# 실제 A: 제가 영원을 약속할게요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 사랑이 뭘까?
# 실제 A: 신뢰입니다.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 너무 잘하는 후배가 들어왔어
# 실제 A: 배울 점은 배우세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이번에는 생리통 너무 아파
# 실제 A: 약을 먹거나 병원에 가보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 걔 앞에만 서면 말이 안 나와
# 실제 A: 무슨 말을 할지 연습해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 용돈 줘
# 실제 A: 저는 돈이 없어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 떠난 그녀를 제 마음속에서 이제는 놔주려 합니다
# 실제 A: 결국 해내고 있네요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 머릿속이 복잡해
# 실제 A: 잠깐 시원한 바람좀 쐬고 오세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 오늘도 끝
# 실제 A: 내일의 시작이죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내 존재를 알리고 싶어
# 실제 A: 우연을 가장해서 여러 번 마주쳐보세요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 수제 빼빼로 어때?
# 실제 A: 먹어보고 싶어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 4년4개월간의사랑이끝났네
# 실제 A: 사랑은 끝나도 당신의 시간은 여전히 진행 중인 걸 잊지 마세요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 하루하루 너무 힘드네
# 실제 A: 다른사람에게 기대보는 건 어떨까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 서비스센터 가야겠네
# 실제 A: 미루지말고 바로 가보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 상처 안받아봤어?
# 실제 A: 저도 상처를 받아봤지요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 믿는 게 아니었어
# 실제 A: 한번더 기회를 주세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 가슴이 아파
# 실제 A: 가슴 아픈 만큼 행복해지세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 사랑이 뭔지 넌 알아?
# 실제 A: 저도 잘 모르겠어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 스트레칭 해야되는데
# 실제 A: 내일은 더 예뻐지겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내가 좋아하는지 그 애가 아예 몰라.
# 실제 A: 조금은 티를 내봐야죠.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 인사드리러 갔는데 파혼하는게 나을것 같아
# 실제 A: 이혼이 아니라 다행입니다.
# 모델 A: 좋은 소식이네요 .
#
# Q: 말하고 후회하면 어떡해
# 실제 A: 말은 주워담을 수 없어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 잊고싶다.
# 실제 A: 잊게 될 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 이젠 놓아주려 해
# 실제 A: 좋은 선택일거라 믿어요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 순간의 화를 못 참겠어
# 실제 A: 성격이 아니라 습관이에요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 여자친구가 잘못을 해도 다 공감해주는게 옳은걸까?
# 실제 A: 공감을 해주면서 잘못을 스스로 깨닫게 해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 여자친구가 너무 어린거 같아.
# 실제 A: 나이 차이는 극복할 수 있어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 점심시간이라도 마음 놓고 쉬고 싶어
# 실제 A: 맛난거 드시고 조금이라도 쉬셔야 할텐데.
# 모델 A: 좋은 생각이에요 .
#
# Q: 미련이 없다고 생각했는데.
# 실제 A: 이별이 사람을 혼란스럽게 하나봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 비오는날
# 실제 A: 마음이 가라 앉죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어진지 세달이 다되가네
# 실제 A: 이젠 괜찮아졌긴 바랄게요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 그녀 생각에
# 실제 A: 잠 못 드는 밤인가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 취업 못하는 기간이 길어진다
# 실제 A: 다음 공채때는 될 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 갑자기 불편한 사이가 된 거 같아
# 실제 A: 관계의 변화가 왔나봅니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 서로 좋아하는 줄 알았는데 짝사랑이었네요.
# 실제 A: 안타깝게 생각해요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 그동안 보내왔던 시간.
# 실제 A: 행복했길 바랄게요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 집에서 먼곳으로 데이트를 자주 가야하는데 꼭 차를 사야할까?
# 실제 A: 비용을 따져보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 준비할 시간을안주네
# 실제 A: 인생은 예측하기 힘들어요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 뭔 참견이야
# 실제 A: 저는 도움이 되고 싶어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 드레스 입어보는 거 재밌어!
# 실제 A: 여러벌 입어보고 마음에 드는걸로 선택하세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 시간을 갖자는 무슨 의미일까?
# 실제 A: 생각을 할 시간이 필요할 수 있어요. 이별이 다가왔을지도.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 등록금 비싸다
# 실제 A: 그러게 말이에요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 넌 고민이 뭐야
# 실제 A: 저는 고민이 없어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 결국 헤어짐이 찾아오네
# 실제 A: 언젠간 올 시기였을거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 냉장고가 텅비었어
# 실제 A: 장 보러 가봅시다.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 이별후 너무 외로워ㅠ
# 실제 A: 이별의 빈자리가 느껴지니까요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 침묵
# 실제 A: 침묵이 오히려 도움이 될 때가 있을 거예요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 너에게 쓴다
# 실제 A: 감성적이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 소개팅 나온 여자애가 너무 좋은데 나만 좋아하는거같아. 어떻게 날 좋아하게하지?
# 실제 A: 매력을 마음껏 어필해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 짝남 전여친 못잊는거 보는게 너무 맘이 아파.
# 실제 A: 그것을 지켜볼 수 밖에 없는게 제일 속상해요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 헤어진 연인의 새로운 사랑
# 실제 A: 이젠 그분을 놓아주세요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 연애는 하기 싫은데 썸은 타고 싶어.
# 실제 A: 시작하기 전 두근거림을 더 좋아하나 봐요. 아니면 연애에 대한 두려움을 가지고 있을 수도 있을 듯 합니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 내 남사친이랑 잘되고 싶어 그는 나를 여자로 봐줄까?
# 실제 A: 이성으로 어필해야죠.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 신혼여행 가서 돌아오기 싫다
# 실제 A: 휴가를 붙여보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 난 잘지내고 있어
# 실제 A: 다행이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 주름살이 조금씩 생긴다.
# 실제 A: 있어도 예뻐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 1년4개월의 종지부를 찍네.
# 실제 A: 충분히 슬퍼하고 충분히 아파하다가 이겨내세요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 이별하는게 맞는거겠죠
# 실제 A: 고민하고 있다면 그게 맞을거예요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 이별한지 8일째
# 실제 A: 어찌보면 짧지 않은 시간.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 감정조절이 안되서 문자 보냈네
# 실제 A: 문자가 나을 수도 있겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이제 내 짝남 못봐. 군대 가거든.
# 실제 A: 서운하겠어요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 유부녀 됐어!
# 실제 A: 축하해요!
# 모델 A: 그게 인생이죠 .
#
# Q: 썸 타는 중인데 너무 인기 많아서 빼앗길까봐 걱정됨.
# 실제 A: 그러면 얼른 쟁취하세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 나도 좀 살게 연락 좀 하지마
# 실제 A: 차단하고 살아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 여친이 외박이 안돼
# 실제 A: 가끔은 선의의 거짓말도 필요하답니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 내 얼굴이 읽히나
# 실제 A: 포커페이스를 유지해보세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 딱 좋아
# 실제 A: 현재를 즐기세요!
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 지금 생각하고 있는건 망상 일뿐입니다
# 실제 A: 누가 되었든 상상할 수 있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 너무 불공평한거 같애
# 실제 A: 남과 비교하지 마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 노력해도 잘 안되는 공부
# 실제 A: 잘못된 방법을 하고 있는 건 아닌지 살펴보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 사랑니 나나봐
# 실제 A: 아프겠어요.
# 모델 A: 사랑은 때론 잔인하죠 .
#
# Q: 빨리 일상속으로 돌아가고픈데.
# 실제 A: 지금도 일상이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 여러명이랑 타는 것도 바람 피는 거야?
# 실제 A: 바람 피우는 건 아닌데 이미지가 안 좋아질 거 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 카톡사진을 보니 눈물이 나네
# 실제 A: 카톡 사진 보지 못하게 지웁시다.
# 모델 A: 그게 인생이죠 .
#
# Q: 삼년 사랑하고 이별한지 몇 시간
# 실제 A: 긴 시간인만큼 실감이 나지 않겠죠.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 선 결혼 후 연애 해도 될까?
# 실제 A: 무엇이 먼저든 마음만 있으면 돼요.
# 모델 A: 그게 인생이죠 .
#
# Q: 일을 나만 해
# 실제 A: 일 분배를 다시 요청해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 밤이되니깐 감수성 터짐
# 실제 A: 새벽은 감수성 더 터지니 얼른 주무세요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 숙취 때문에 지끈거려
# 실제 A: 약을 드셔보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 같이 마지막으로 다녀온 여행 생각나
# 실제 A: 새로운 여행을 떠나보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이제 때론 괜찮기도 해
# 실제 A: 그렇게 익숙해져 가나봐요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 도서관 책 반납 안햇다
# 실제 A: 까먹었나봐요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 3개월째
# 실제 A: 아프지 마요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 모임에서 만났어
# 실제 A: 꿩 먹고 알 먹고네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 붙잡고 싶습니다.
# 실제 A: 후회하지 않을 자신 있다면 붙잡으세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 사랑할 자격 없는 사람이야
# 실제 A: 사랑에는 조건이 필요없어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 이제는 정말 끝
# 실제 A: 맘고생 많았어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 남친한테 교회 가자고 하고 싶어
# 실제 A: 마음을 열 때까지 설득해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 머리 다듬어 달라고 그럴까?
# 실제 A: 다듬기만해도 괜찮을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 그저 그런 연애
# 실제 A: 그게 제일 힘들어요.
# 모델 A: 사랑은 때론 잔인하죠 .
#
# Q: 팬미팅 재밌다.
# 실제 A: 성덕이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이별은 받아들이는 것
# 실제 A: 쉬운 일이 아니라는 거 잘 알고 있어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 행복해하는 널보며
# 실제 A: 많이 사랑했나봐요.
# 모델 A: 그게 인생이죠 .
#
# Q: 행운을 빌어줘
# 실제 A: 제 행운까지 모두 드리고 싶네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸남한테 책 같이 읽자고 할까?
# 실제 A: 도서관 데이트나 서점 데이트 좋을 거 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 사람은 감정적인 동물이라
# 실제 A: 하루에도 몇 번씩 이랬다 저랬다 할 수 있어요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 애완동물 키우고 싶은데 아빠가 키우지 말래
# 실제 A: 이유가 있을 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 서점에 들렀어
# 실제 A: 마음의 양식을 채우길 바랄세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 잊을 수가 있을까
# 실제 A: 힘들긴 하지만 시간이 약이라는 사실을 잊지 말아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 사랑을 기다리고 있어
# 실제 A: 능동적으로 찾아보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 잘못 쓴 거 엄청 많아
# 실제 A: 마음을 손이 따라와주지 않죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 빨리 찾아온 사랑
# 실제 A: 인생은 타이밍이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 배우자라고 하니까 이상해
# 실제 A: 익숙해져야죠.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 나랑 놀자
# 실제 A: 지금 그러고 있어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 덕수궁 돌담길 걸었어
# 실제 A: 로맨틱하네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 지난 갑작스러운 이별통보
# 실제 A: 어떤 이별은 갑작스럽기도 해요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 내가 그사람한테 필요했으면 좋겠어
# 실제 A: 사적 영역에 깊숙이 들어가보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 짝녀가 저한테 관심이 없는 것 같은데도 계속 연락해도 될까요.
# 실제 A: 아직 확실한게 아니라면 연락해보는게 좋을 것 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 이제야 오래전 상대방이 아팠던걸 이해했어.
# 실제 A: 다음 번의 사랑에선 좀 더 신중할 수 있게 된 거예요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 바쁘네
# 실제 A: 바빠도 힘내세요!
# 모델 A: 좋은 생각이에요 .
#
# Q: 진짜헤어졌네 결국
# 실제 A: 많이 힘들었을 거라 생각해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어짐이 힘든이유
# 실제 A: 사랑했으니까요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 노래 듣는데 참 공감이 되네
# 실제 A: 딱 들어맞나봅니다.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 학생 데이트 코스 추천
# 실제 A: 도서관 데이트 추천해요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 마지막입니다.
# 실제 A: 마지막을 잘 마무리 해야 시작도 잘 할 수 있을 거예요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 친구랑 힐링하고 왔어
# 실제 A: 기분이 좋아 보이네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 피크닉 가고 싶다
# 실제 A: 오늘 피크닉 가기 좋은 날이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 빡빡한 일상
# 실제 A: 여유가 생기길 바랍니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 점 보러 가볼까?
# 실제 A: 재미로 보기 좋죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 재밌는게 없어
# 실제 A: 변화가 필요해보여요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 인정 받고 싶은거 당연한 거 아니냐
# 실제 A: 열심히 하다보면 받을 수 있을 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 요즘에는 외국어도 잘해야하나봐
# 실제 A: 원하는 게 점점 많아지는 세상이에요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 짝남과 자연스럽게 친해질 수 있는 방법 있을까?
# 실제 A: 공통 관심사를 찾아보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 음식 편식하는 사람 사겨도 돼?
# 실제 A: 사귀면서 편식을 고쳐봐도 좋을 것 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 글을 쓰게 되네
# 실제 A: 글을 쓰다보면 정리가 될 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 원피스 입을까
# 실제 A: 너무 이뻐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 환기 좀 해야할까?
# 실제 A: 매일 환기하는 게 좋대요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 이별은 진짜 비겁한 짓 같아.
# 실제 A: 똥차가 지나갔다 생각하세요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 가스비 장난 아님
# 실제 A: 다음 달에는 더 절약해봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 집안일을 못하겠어
# 실제 A: 조금씩 잘 하게 될거예요
# 모델 A: 좋은 생각이에요 .
#
# Q: 사랑하는 사람을 알아보고 싶어.
# 실제 A: 알아보지 못한 만큼 더 사랑해주세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 남편은 진짜 남의 편인가?
# 실제 A: 당신 편으로 만들어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 완전 헤어짐 극복 방법 있을까
# 실제 A: 바쁘게 살거나 취미생활을 해서 다른 생각을 못하게 하는 것 추천해드려요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 머리 깎아야지
# 실제 A: 예쁘게 깎아요!
# 모델 A: 좋은 생각이에요 .
#
# Q: 요구하거나 제안했을 때 뭐라고 리액션해야할지 모르겠어
# 실제 A: 생각이 너무 좋은 것 같고, 왜 나는 그런 생각을 못했는지 등으로 크게 반응해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 오늘 하루도 잘 버티고 계신가?
# 실제 A: 잘 지내고 있을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 생각 안나
# 실제 A: 잘 생각해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 영화관 알바하면 좋겠다.
# 실제 A: 영화를 많이 볼 수 있어서 좋을 것 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이별 한달차입니다
# 실제 A: 괜찮아요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 첫눈이 올때 같이 있고 싶다
# 실제 A: 그런 사람이 있다니 부럽네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 만나자
# 실제 A: 말해보세요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아닐 거예요 .
#
# Q: 냄새 나면 어쩌지?
# 실제 A: 깨끗이 씻어보고 섬유유연제나 바디워시, 바디로션, 향수 등을 사용해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아파
# 실제 A: 병원에 가야죠.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 니 상사는 누구니
# 실제 A: 제가 상사예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝녀가 내 톡은 안 읽고 프사 바꿈.
# 실제 A: 아쉽지만 마음을 접는 편이 좋겠네요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 가끔 궁금해
# 실제 A: 그 사람도 그럴 거예요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 헤어진 사람이 생각나는데 어떻게 견디지
# 실제 A: 다른 관심사를 만들어보세요. 취미 생활도 많은 도움이 됩니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 공무원 되고 싶다
# 실제 A: 준비해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 일어나자마자 우울
# 실제 A: 달콤한 차라도 한 잔 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 6년의 만남. 이별을 준비하고 있습니다.
# 실제 A: 힘들겠지만 천천히 보내주세요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 누구나 궁금할법한 이야기
# 실제 A: 당신의 이야기.
# 모델 A: 좋은 생각이에요 .
#
# Q: 저도 연애하고 결혼할 수 있을까
# 실제 A: 더 좋은 사람 만나서 알콩달콩 연애하고 행복한 결혼생활 할 수 있을 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 잘가
# 실제 A: 안녕.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 블랙박스 제대로 찍혔을까
# 실제 A: 지금 확인해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어린이집 입학식 꼭 참석해야하나?
# 실제 A: 가능하면 참석하는 게 좋겠죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 많이 좋아하던 전여친에게 연락해도될까?
# 실제 A: 연락은 자유지만 후회는 할 수도 있어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 비타민 먹어야지
# 실제 A: 꼬박꼬박 챙겨 드세요.
# 모델 A: 맛있게 드세요 .
#
# Q: 집에 친구 초대하려고
# 실제 A: 모처럼만에 즐거운 시간 보내겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 괜찮아진 줄 알았는데.
# 실제 A: 괜찮은 척 하고 있던 걸 수도 있어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 싸게 팔길래 샀어
# 실제 A: 득템 했네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 기분이 묘한 하루네
# 실제 A: 싱숭생숭한 하루였나요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 여자친구가 나 사랑하는 건지 모르겠어
# 실제 A: 확신이 필요한가봐요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 사랑이 익숙해지면 정으로
# 실제 A: 정도 사랑의 일부니까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝남이랑 약속 파토 남.
# 실제 A: 아쉽네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 첫이별후 제가 가장 충격먹었던게.음
# 실제 A: 천천히 말해봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 새벽되니까 감성적으로 되네
# 실제 A: 조용하니 혼자 생각하기 좋죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오디션 도전해볼까
# 실제 A: 도전 응원합니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 하 고놈의 술이 뭔지 참
# 실제 A: 술이 웬수죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어른이 된다는 건 뭘까
# 실제 A: 사춘기로부터의 일시적 휴식에 불과하죠.
# 모델 A: 좋은 소식이네요 .
#
# Q: 썸 맞는지 궁금
# 실제 A: 계속 연락하고 만나자고 해야 썸인 듯합니다.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 재회하면 또 그렇겠지
# 실제 A: 아마 그럴 거예요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 사랑하는 사람은 표시가 있었으면 좋겠다
# 실제 A: 당신이 그 신호를 못 찾은게 아닐까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 좋아하는 사람한테 거절 당할까봐 두려워.
# 실제 A: 충분히 그렇게 생각할 수 있어요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 해주기 싫어
# 실제 A: 상처받았나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 책만 펴만 잠와
# 실제 A: 눈꺼풀의 무게를 이겨내세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 현실과 타협해야하는 이별
# 실제 A: 현실적인 문제가 중요할 때가 있죠.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 1년 동거 중인데 계속 좋아
# 실제 A: 서로 깊게 알게되면서 더 좋아졌나봅니다.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 너무 힘들다
# 실제 A: 지금 무슨 말을 해도 와닿지 않겠지만 잘 이겨낼 거라 믿어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 믿지 말껄
# 실제 A: 한번더 기회를 주세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝사랑 하던 사람 못 잊을 것 같애.
# 실제 A: 생각처럼 쉽지 않지요.
# 모델 A: 이별은 언제나 좋죠 .
#
# Q: 그사람도 아주 가끔은 내 생각해줬으면 좋겠어
# 실제 A: 사소하면서도 아련한 소원이네요.
# 모델 A: 사랑은 알다가도 모르는게 아니에요 .
#
# Q: 8년의 연애의 끝에 와있습니다.
# 실제 A: 끝은 항상 힘들지요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 황당해서 말도 안 나와
# 실제 A: 너무 신경쓰지마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 미치겠어
# 실제 A: 힘드시죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸 타는 중인데 권태기가 온 듯
# 실제 A: 만나서 극복하세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 받아들여야지
# 실제 A: 받아들일 때가 되었나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한달이 10년 같은.
# ...
# 실제 A: 짝사랑 앞에서 누구나 한 없이 작아지나봐요. 자신감을 가지세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 처음엔 좋았는데
# 실제 A: 그 사람의 좋은점을 생각해보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 숙제가 쌓여가
# 실제 A: 지금도 늦지 않았어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 사랑한다는 말 쉽게 안 나와
# 실제 A: 감정을 표현한다는게 어렵죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 휴~~ 이제 글쓰는것도 멈춰야 할까
# 실제 A: 글 쓰면서 정리가 되기도 해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 스키 처음 타 봐!
# 실제 A: 강습 받아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 점심 뭐 먹을까
# 실제 A: 맛있는 거 드세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 날씨 건조한 거 같애
# 실제 A: 미스트나 가습기, 젖은 수건 등을 사용해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 치과 가야 하나
# 실제 A: 근처 치과에 가보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 시간 잘 떼우는 방법
# 실제 A: 친구와 수다를 떠세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 입이 방정이야
# 실제 A: 말조심하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 몇일만에 또 찾아갔네요
# 실제 A: 후회하지 않을까 생각이 드네요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 좋아하는 애 친구한테 다같이 만나자고 말해도 돼?
# 실제 A: 다같이 만나면 재미있기는 하겠네요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 자꾸 날카로워진다
# 실제 A: 너무 신경 곤두세우지 마세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 헤어진 여자친구
# 실제 A: 이제 그리워하지마세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 발렌타인데이 선물 비싸
# 실제 A: 초콜릿 녹여서 예쁘게 만드는 것도 재밌죠
# 모델 A: 뭘 입어도 멋져요 .
#
# Q: 기분 나쁜 농담을 계속하고 있어
# 실제 A: 정색 한번 해주세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 하아 너무 많이 힘드네 ㅜㅜ
# 실제 A: 맛있는 거라도 먹고 기분을 전환 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 중국어 배울려면 학원 다녀야 할까
# 실제 A: 혼자해도 좋고 학원을 다녀도 좋아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 환경 때문에 헤어진 여자친구
# 실제 A: 현실적인 문제가 중요할 때가 있죠.
# 모델 A: 좋은 소식이네요 .
#
# Q: 발 맞춰 걷는 게 좋더라
# 실제 A: 당신은 군대가 체질에 맞는거 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 밤에 잠이 안 와
# 실제 A: 양을 세어 보아요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 살만 찌네
# 실제 A: 맛있는 거 먹고 기분이 나아졌다면 걱정은 넣어두세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 어이없는연애? 끝난걸까, 진행중일까.
# 실제 A: 언젠간 선택을 해야 할 것 같아요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 딱 오늘 새벽 헤어졌습니다.
# 실제 A: 달 어스름에 더 울적하겠어요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 신혼집 꾸미고 싶어
# 실제 A: 하나씩 꾸며보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남편복 있다는 의미가 뭐야?
# 실제 A: 남편 때문에 행복하다는 거 같아요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 혜진아. 내 맘이 너에게 확정되기 전에 날 떠났어야지
# 실제 A: 말처럼 쉽지 않죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 집 나가서 혼자 살고 싶다.
# 실제 A: 혼자 사는 것도 나쁘지 않아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 문화센터라도 가야겠다.
# 실제 A: 다양하게 배우면 좋죠.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 조심조심
# 실제 A: 안전이 최고죠!
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어지고 힘들다.
# 실제 A: 헤어졌으니까요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 여러번 재회 그리고 헤어짐
# 실제 A: 많이 지쳤을 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 헤어졌는데도 좋아하는거 별로임?
# 실제 A: 헤어지면 남이죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 애인이 있는데 좋아하는 사람이 생겼어요.
# 실제 A: 마음으로 바람피는 거네요.
# 모델 A: 마음이 복잡하겠어요 .
#
# Q: 나한테 뒷모습만 보여줬어
# 실제 A: 이제 앞모습을 볼 차례네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 반복되는 맘의 준비
# 실제 A: 그렇게 성장하나봐요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 짝녀한테도 철벽쳐요. 성격이 왜 그럴까요.
# 실제 A: 두려운게 있는게 아닐까요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 사업 구상
# 실제 A: 성공하길 바랍니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 간단하게 사랑이라는건.
# 실제 A: 여러번 해도 어려워요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 피크닉 고고
# 실제 A: 오늘 피크닉 가기 좋은 날이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나한테도 관심 있어 보이는데 연락해볼까?
# 실제 A: 먼저 연락해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 막차 놓쳤다
# 실제 A: 어쩔수없죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이별극복후 새로운 설렘
# 실제 A: 좋은 소식이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 7년사귄 남자친구의 유흥업소 방문사실을 알아버렸습니다
# 실제 A: 그런 사람 못 고쳐 씁니다. 헤어지세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 물건 사는것도 힘드네
# 실제 A: 칼로리 소모가 꽤 돼요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 설렘이 사라진 거 같아
# 실제 A: 편한 사랑도 사랑이에요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 즐기며 살고 싶어
# 실제 A: 현재를 즐기면서 행복하게 사세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 격려 좀 해줘
# 실제 A: 잘하실 거예요!
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 어때?
# 실제 A: 괜찮은 사람이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남편이 효자인 거 같아
# 실제 A: 좋게 생각해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 보고싶은데
# 실제 A: 볼 수가 없군요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 사랑으로 가능한 것?
# 실제 A: 바로 연애죠.
# 모델 A: 그게 인생이죠 .
#
# Q: 엄마가 동생이랑 차별해
# 실제 A: 그런 의도는 아니셨을거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 헤어진지 3개월째입니다.
# 실제 A: 생각보다 많은 시간이 지났네요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 이력서 광탈 중이야
# 실제 A: 좌절하지마세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 헤어지는게 맞는걸까?
# 실제 A: 마음 가는 대로 해보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 맨날 썸만 타고 깨짐.
# 실제 A: 제대로 된 표현을 했는지 생각해보세요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 여자친구가 술을 못마시는데 분위기를 좋아해서 자주 술마시러가는게 고민이야.
# 실제 A: 술 마시기 전에 술 깨는 약을 선물해주세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 전 남친이랑 헤어진지 오래됐는데 좋아하는 사람이 없어.
# 실제 A: 조급하게 생각하지 말아요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 좋아하는 남자애에게 어떤 생일선물을 주면 좋아할까요?
# 실제 A: 필요한 게 뭔지 살펴보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 매순간 넘 보고 싶어
# 실제 A: 잠깐의 허상일 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 4년 사귄뒤 이별. 어느새 5달이 다되어가네여.
# 실제 A: 만났던 시간이 긴 만큼 많이 힘들겠어요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 의자 너무 불편해
# 실제 A: 의자를 바꿔보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아하는 사람한테 적극적인 여자 별로야?
# 실제 A: 적극적이면 오히려 더 좋을 것 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 덤덤
# 실제 A: 덤덤해졌나봐요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 이별 2달차 아직도 못 잊고 원망
# 실제 A: 이해해요. 그렇지만 원망은 자신을 더 힘들게 할 뿐이에요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 남자친구가 데이트 통장을 제안하는데 어떻게 생각해?
# 실제 A: 합리적인 소비가 가능할 거 같아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 안될거 같아
# 실제 A: 될 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 왜그랬어?
# 실제 A: 자신에게 물어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남자친구가 자존심이 너무 쎄
# 실제 A: 사랑한다면 자존심을 굽힐 줄도 알아야 겠죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 나 잘할 수 있을까
# 실제 A: 지금처럼, 지금보다 더 잘할 수 있을 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 막장으로 가네
# 실제 A: 잠시 쉬어가는 거 뿐이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 좋아하는 남자애 없나봄. 넘 외로워.
# 실제 A: 좋아하는 사람이 생길 거예요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 같은하늘 다른공간
# 실제 A: 같은 하늘 아래 숨 쉬고 있어요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 그는 내 마음을 알까?
# 실제 A: 표현하지 않으면 몰라요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 난 많이 노력한 거 같은데
# 실제 A: 중요한 건 노력하는 과정이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 사랑스러운 눈빛
# 실제 A: 사랑 받는다는 느낌 팍팍 받았겠네요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 짝사랑 중일 때 장점.
# 실제 A: 짝사랑 상대 생각에 설레는 것.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 대체불가한 사람이 되고 싶어
# 실제 A: 지금도 그래요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아하는 사람 생겼으면 좋겠어.
# 실제 A: 좋은 사람이 생길 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 나 좀 건들지 말라고 해
# 실제 A: 많이 지쳤나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 첫눈 오는날 만나고 싶다
# 실제 A: 그런 사람이 있다니 부럽네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 말을 좀 잘 하고 싶어
# 실제 A: 말 잘하는 사람들 따라 연습해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 괜찮아졌는줄 알았는데. . .
# 실제 A: 조금만 더 힘내세요.
# 모델 A: 마음이 허전하신가봐요 .
#
# Q: 인간관계 관리하는 거 힘들어
# 실제 A: 너무 믿지 마세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 사랑이후 다시 세상은 회색빛으로.
# 실제 A: 다시 무지갯빛이 될 거예요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 사랑은 주고 받는 거지?
# 실제 A: 사랑은 한 없이 줘도 아깝지 않은거라고 생각해요.
# 모델 A: 그게 인생이죠 .
#
# Q: 모르는 사람이 자꾸 쳐다봐
# 실제 A: 혹시 반한 걸 수도 있어요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 헤어지자고 말했어 마음이 찢어지네
# 실제 A: 말한 사람도 힘들죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 법을 피해가는 사람
# 실제 A: 능력이긴 하지만 꼬리가 길면 밟힐 거예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 오늘 무너졌어.
# 실제 A: 힘내지 않아도 돼요. 조금 쉬어가세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 세상이 감미로워보여
# 실제 A: 사랑에 빠졌나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 약속 끝나고 짝남에게 집에 데려달라고하면 오해하려나?
# 실제 A: 오해해도 하는 게 좋을 것 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 또 헤어진 사람의 sns를 봤네
# 실제 A: sns를 삭제하는게 어떨까요. 미련만 남을 뿐이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정말 제가 이해가 안갈 정도로 잘못한건가?
# 실제 A: 그분에겐 감당이 안되었을 수도 있겠어요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 머리 냄새날텐데
# 실제 A: 항상 청결하게 관리하세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 전여친하고 짝녀가 친구야.
# 실제 A: 신경 쓰이는 상황 같아요.
# 모델 A: 사랑의 예의가 없는 사람이네요 .
#
# Q: 헤어진지 한 달 조금 넘었는데 여전히 힘드네
# 실제 A: 이별에는 면역이 힘든가봐요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 헤어진지 한달 조금 넘었어
# 실제 A: 금방 지나갈 거라 생각해요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 고백합니다
# 실제 A: 성공하길 바랄게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 넘 많이 먹었다.
# 실제 A: 산책 좀 해야겠네여.
# 모델 A: 좋은 생각이에요 .
#
# Q: 짝사랑한테 빼빼로 줘도 될까
# 실제 A: 용기를 내요!
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 꿈이 자꾸 바뀌어
# 실제 A: 많으면 많을 수록 좋죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남자친구가 표현을 하게하고싶은데 방법을 잘 모르겠어.
# 실제 A: 작은 표현에 감동받았다고 해봐요.
# 모델 A: 그건 좀 아닌건 좀 아닌건 아니라고 말하세요 .
#
# Q: 놀이공원 알바 재밌대
# 실제 A: 특별한 경험이 될 것 같아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 비밀번호 자꾸 바꾸래
# 실제 A: 보안상 그게 좋죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 짝남있던 단톡방에 술 마시고 실수했어.
# 실제 A: 마음이 아프네요. 큰 실수 아니었길 바랄게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 할줄 아는 게 없어
# 실제 A: 잘해야 한다는 부담감을 버리세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 연예인 되면 피곤하겠지?
# 실제 A: 아무래도 사생활이 적으니까요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 셀카 잘 찍어서 올리고 싶다.
# 실제 A: 얼굴이 준비되어야 겠지요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 대학 나온 거 부러워
# 실제 A: 부러우면 지는 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 가족관계 알려줘
# 실제 A: 저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 집이 너무 지저분해
# 실제 A: 청소기를 돌려보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 키가 안 커
# 실제 A: 지금도 충분해요.
# 모델 A: 맛있게 드세요 .
#
# Q: 용돈 벌써 없어
# 실제 A: 알바해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 좋아했던 기억 영원히 없앨 수는 없을까.
# 실제 A: 없애는 게 아니라 무덤덤해지는 걸 거예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 사랑 지키는 방법
# 실제 A: 자신과 서로를 존중하고 마음을 표현해보세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 본인을 좋아하는게 확실한 여자와 친구가 될 수 있어?
# 실제 A: 그 사람을 위해서는 그러면 안돼요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 버릴 건 버려야 겠지
# 실제 A: 잘 버리는 것도 중요해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 서로의 조각
# 실제 A: 기억의 편린일 뿐이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 남사친 좋아하는 내가 잘못이지.
# 실제 A: 잘못은 아니에요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 여자친구 만나고왔어~
# 실제 A: 좋은 만남이었길 바랍니다.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 구썸남 보고싶어.
# 실제 A: 썸으로 끝날 사이가 아니었네요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 하루 종일 붙어 있고 싶어
# 실제 A: 뭐든 함께하려는 것도 좋겠지만 오래 붙어잇는다고 해서 사랑이 더 커지거나 깊어지지 않아요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 걸지 못한 전화
# 실제 A: 걸지 말아요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 분위기 좋은 곳에서 데이트하고 싶어
# 실제 A: 매일 가고 싶네요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 발표 준비 너무 힘들어
# 실제 A: 잘할 수 있을 거예요. 조금만 더 힘내세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 천재 같아
# 실제 A: 감사합니다.
# 모델 A: 좋은 생각이에요 .
#
# Q: 칼국수 어때?
# 실제 A: 맛을거 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이별한지 3개월 째.
# 실제 A: 좀 나아졌길 바랍니다.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 결정은 빠르면 빠를 수록 좋겠지?
# 실제 A: 자신을 위한 결정을 내리길 바라요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나만 너무 좋아하는거 같애
# 실제 A: 더 표현해 달라고 말해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 난 천재다
# 실제 A: 제가 더 천재예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 시험 앞두고 짝사랑하는 여자가 생겼어요.
# 실제 A: 신경 쓰이는 일이 생겼다니 조심하세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 전여친한테 남친이 생겼네
# 실제 A: 이제 그녀를 잊으세요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 위로받고 싶은 날
# 실제 A: 제가 위로 많이 해드릴게요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정말 힘듭니다
# 실제 A: 힘이 되지 않겠지만 힘내세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 사과해야 하나?
# 실제 A: 사과할 건 사과해야죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 정말 난감하다
# 실제 A: 난처한 일이 있었나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 썸남 생일 때 편지 줘도 될까
# 실제 A: 진심어린 손편지는 누구나 좋아하죠.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 썸남 졸업하는데 가도 되나?
# 실제 A: 상대에게 정확히 물어보는게 좋아요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 행복해라 불행해도 좋고
# 실제 A: 행복이 있으니 불행도 있고 불행이 있어서 행복도 빛나지요. 인생이 그런가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 술한잔해야 하루가 가
# 실제 A: 술 마시다가 더 무너져요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 친구의 남자친구가 눈에 들어와
# 실제 A: 만나지도 연락하지도 말아보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 사랑한다고 말해볼까?
# 실제 A: 솔직함으로 사랑을 쟁취하세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 1000일 만난 여자친구와 이별
# 실제 A: 더 오래 만날 사람 만날 거예요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 어떻해야 할까
# 실제 A: 어떤 선택을 하든 잘 할 수 있을 거예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 도움되시길
# 실제 A: 도움이 될 거라 생각해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 3년연애이별
# 실제 A: 힘들겠지만 잘 이겨낼 거예요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 바람 불어 좋은 날.
# 실제 A: 살랑살랑.
# 모델 A: 좋은 생각이에요 .
#
# Q: 일 못하는 사수랑 일하는 거 힘드네
# 실제 A: 참고 견뎌보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 덜 좋아하는 방법만 알면 힘들지 않을텐데
# 실제 A: 마음은 컨트롤할 수 있는 게 아니라 힘들겠어요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 썸인지 알려면
# 실제 A: 어느 정도 시간과 연락과 관심이 필요하겠네요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 몇일 동안의 나의 이야기.
# 실제 A: 들려주세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 죽을 때까지 함께하고 싶다
# 실제 A: 프로포즈해보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 무너진 밤
# 실제 A: 아침이 올 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오늘 침대밖으로 안 나가야지
# 실제 A: 침대와 한몸이 되어 푹 쉬세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 친구랑 술 한잔 기울이고 들어왔습니다.
# 실제 A: 기분이 조금이나마 나아졌길 바랍니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 오늘 너무 힘들다
# 실제 A: 고생 많았어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나한테 관심 있는게 맞을까?
# 실제 A: 직접적이든 간접적이든 의사를 확실히 밝혀보세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 여자친구가 살이 너무 쪄서 고민임.
# 실제 A: 같이 운동해봐요.
# 모델 A: 힘 빠지는 이야기네요 .
#
# Q: 그 사람이 날 좋아하는 이유가 뭘까.
# 실제 A: 그 자체죠.
# 모델 A: 마음이 복잡하겠어요 .
#
# Q: 애들이 썸 타냐고 물어봐
# 실제 A: 다른 사람들이 알 정도인가 봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 망고빙수 맛있다
# 실제 A: 디저트는 언제나 맛있어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나 오늘 상 받았지롱
# 실제 A: 축하드려요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 지금 연락 왔어
# 실제 A: 저도 긴장이 되네요.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 아침 일찍 일어나 조깅하고 있어
# 실제 A: 건강에 좋은 습관이네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 운명인 것 같아
# 실제 A: 인연인가 봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 보일러 틀어놓고 나왔어.
# 실제 A: 이번달 난방비가 많이 나오겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 처음에는 별로 였는데 호감 간다
# 실제 A: 볼매인가봐요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 이젠 어쩌죠.
# 실제 A: 생각을 정리해 보세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 그래도 아프다
# 실제 A: 사랑한 만큼 아픔이 오죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 오랜 연애로 가족같은 느낌이야.
# 실제 A: 편한 사람도 찾기 힘들어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 고독한 밤
# 실제 A: 혼자가 아니에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 고기 먹고 싶어
# 실제 A: 저기압에는 고기앞이죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 욕을 퍼붓고 왓어
# 실제 A: 마음이 후련하길 바랍니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 전남친이 자꾸 생각나
# 실제 A: 세상은 넓고 사람은 많아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 친구인데 고백해도 될까?
# 실제 A: 솔직한 마음으로 다가가보세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 썸인데 어디 가는게 좋음?
# 실제 A: 일단 분위기 좋은 카페를 가는 건 어떨까요?
# 모델 A: 최대한 이해해보세요 .
#
# Q: 저 사람이 왜 자꾸 볼까?
# 실제 A: 혹시 반한 걸 수도 있어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 여자친구와 헤어지고 세운 목표들
# 실제 A: 목표를 하나씩 이뤄가길 바랍니다.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 공황증
# 실제 A: 견디기 힘들었을텐데 괜찮은가요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 실망하지 않았으면 좋겠다
# 실제 A: 기대가 높으면 실망을 하죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 매일 아침 정류장에서 마주치는 남자애가 신경쓰여.
# 실제 A: 내일도 만난다면 말을 걸어보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 전여친이 나보다 나은 사람이라는 생각이 자꾸 들어
# 실제 A: 남과 자신을 비교하지 말아요. 자신을 더 사랑해보세요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 남자친구가 입이 험해
# 실제 A: 사람 고쳐쓰는 거 아니에요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 기분이 그지 같아
# 실제 A: 신나는 음악 들어보세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 커피 타는 거 싫다
# 실제 A: 커피는 셀프였으면 좋겠어요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 헤어진 남친의 연락하는 심리
# 실제 A: 헤어진 사이에 연락은 아닌 거 같아요.
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 남자친구가 게임을 너무하는게 고민이야.
# 실제 A: 같이 게임을 해보세요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 친구들이랑 노래방 가고 싶어
# 실제 A: 즐거운 시간이 될 거 같아요
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 격려가 필요해.
# 실제 A: 잘하실 거예요!
# 모델 A: 그건 소액이 아니에요 .
#
# Q: 한쪽이 마음 떠나고 마음 돌리는 방법
# 실제 A: 마음이 떠난 이유를 먼저 생각해봐요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 짝남이 남친이 되었어요.
# 실제 A: 좋은 소식이네요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 헤어진지 한달짼데
# 실제 A: 아직 잊지 못하고 있나봐요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 멘붕
# 실제 A: 얼떨떨할 거예요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 질질 끄는연애 드디어끝이네.
# 실제 A: 맘고생 많았어요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 붙잡으려고
# 실제 A: 많이 노렸했군요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 말하는대로 이루어졌으면.
# 실제 A: 사는 재미가 없을거예요.
# 모델 A: 이제 그만 놓아주세요 .
#
# Q: 여자친구가 너무 좋은데 점 본거에서는 만나지말래.
# 실제 A: 다른 데서도 봐보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 결혼하면 좋을까
# 실제 A: 서로 노력하면 행복할 거예요.
# 모델 A: 그건 좀 아닌 건 아니에요 .
#
# Q: 골프 어려워
# 실제 A: 처음부터 잘하는 사람은 없어요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 찜질방 가면 쌩얼 보여줘야 되나
# 실제 A: 찜질방에서 화장은 아닌거 같아요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 엇갈리지 않았으면 좋겠다
# 실제 A: 타이밍이 안 맞았나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 환승이별 3달째를 앞둬도 힘들다
# 실제 A: 점점 더 괜찮아질 거예요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 오늘도 그냥 그냥
# 실제 A: 소소한 행복을 느껴보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 보험 많이 들었어
# 실제 A: 미래를 더 준비하고 있나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 하품 나와
# 실제 A: 졸린가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어찌해야 할까
# 실제 A: 차분히 생각해봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 쳇바퀴 돌듯 돌아가는 삶
# 실제 A: 그 속에서 가치와 의미를 찾아보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 흠 아무 의미없는거라고 생각하고 싶은데 자꾸 뒤숭숭하네
# 실제 A: 무관심해봐요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 순수한 사람 만나고싶다
# 실제 A: 순수하고 불순한 게 나눠있지 않을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 이별보다 더 아프네
# 실제 A: 많이 힘드셨군요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 결혼 준비하면서 못 보던 모습을 보게 돼
# 실제 A: 본 모습일지도 몰라요.
# 모델 A: 그게 인생이죠 .
#
# Q: 낮술먹는날 우울터짐
# 실제 A: 술 많이 드시면 더 무너져요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 새 신발 샀어
# 실제 A: 좋은 곳으로 데려다 줄 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 어떻게 해야돼?
# 실제 A: 어떻게 도와드리면 좋을까요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 일이 익숙해 지지 않네
# 실제 A: 조금만 더 힘내세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 축구 볼때는 치맥이지
# 실제 A: 보다보면 재미있어요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 평가원 시험 잘 봐야 할텐데
# 실제 A: 평소처럼 잘 볼 수 있을 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 나만 우스워질거 같아
# 실제 A: 스스로 단단해지세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 헤어지고 난뒤 친구?
# 실제 A: 친구가 되기 쉽지 않을 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 일하는 곳 근처 가서 염탐하고 왔네.
# 실제 A: 그분에 대한 궁금증을 접어두셔요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 한달이넘었는데 괜찮은거같은데
# 실제 A: 다행이에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 모른 척 하는 건지 모르는 건지
# 실제 A: 진짜 모르는 걸 수도 있어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이거 사랑인가?
# 실제 A: 당신만이 답을 말해줄 수 있어요.
# 모델 A: 그게 인생이죠 .
#
# Q: 변화를 좀 주고 싶다.
# 실제 A: 긍정적으로 바뀔 수 있어요
# 모델 A: 좋은 생각이에요 .
#
# Q: 시간이라는게 참 사람을 무색하게 만들죠
# 실제 A: 덤덤하게 익숙해지나봐요.
# 모델 A: 그게 인생이죠 .
#
# Q: 결혼식이 너무 많아
# 실제 A: 인맥이 넓으신가봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 배 터지겠다.
# 실제 A: 산책 좀 해야겠네여.
# 모델 A: 좋은 생각이에요 .
#
# Q: 주제 넘은 짓 한거 같아
# 실제 A: 주제를 모를 때가 행복할 때예요.
# 모델 A: 그게 인생이죠 .
#
# Q: 2년째 동거중인데 결혼하려고
# 실제 A: 서로 깊게 알게되면서 더 좋아졌나봅니다.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 마지막 붙이지 못한 이별편지
# 실제 A: 마음에 간직하세요.
# 모델 A: 이별은 언제나 힘들어요 .
#
# Q: 오늘 또 하루 살았네
# 실제 A: 오늘은 약간의 변화를 줘보세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내 짝은 어디있을까
# 실제 A: 같은 하늘 아래 어딘가에.
# 모델 A: 좋은 생각이에요 .
#
# Q: 술 마시고 망가질테닷
# 실제 A: 적당히 드세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 디퓨저 선물 해줄까?
# 실제 A: 좋은 선물이 될 거예요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 여친 집에 있는 내 물건들이 돌아왔네
# 실제 A: 속상했겠어요.
# 모델 A: 좋은 소식이네요 .
#
# Q: 손 시려
# 실제 A: 장갑 하나 사셔야겠어요,
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 사표 낼까?
# 실제 A: 뒷감당은 준비하세요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 차별이 제일 싫어
# 실제 A: 차별을 하다니 못난 사람들이군요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 헤어진지 3달만에 새로운 남자가 생긴 그녀.
# 실제 A: 이젠 그녀를 놓아주세요.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 건강하게 다이어트 하는 방법
# 실제 A: 적게 먹고 많이 움직이세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 새학기 학용품 사야지
# 실제 A: 새학기 준비 잘 하세요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 내일 발렌타인데이인데
# 실제 A: 다른 사람 만나요.
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 괜히 기다렸어
# 실제 A: 누군가를 기다린다는게 쉬운게 아니죠.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아직 마음을 모르겠는데 고백해도 돼?
# 실제 A: 확실한 생각이 들 때 하세요.
# 모델 A: 그게 인생이죠 .
#
# Q: 친구도 연인도 아닌 그런사이의 끝
# 실제 A: 후유증이 클 수도 있겠어요.
# 모델 A: 사랑은 때론 잔인하죠 .
#
# Q: 반 배정 내가 원하는 대로 될까
# 실제 A: 잘 되길 바랍니다.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 어렵네
# 실제 A: 쉽지 않을 거예요.
# 모델 A: 많이 힘들었을 거라 생각해요 .
#
# Q: 사랑의 끝이 뭐야?
# 실제 A: 사랑하지 않는 것이죠.
# 모델 A: 사랑은 알다가도 모르니까요 .
#
# Q: 뻘짓 한 느낌 싫다
# 실제 A: 바람 좀 쐬고 오시면 좋은텐데.
# 모델 A: 좋은 생각이에요 .
#
# Q: 하루하루 늙어가
# 실제 A: 우리는 태어날 때부터 늙어가고 있어요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 이별한지 4개월째.
# 실제 A: 마음은 좀 정리 되어가길 바랍니다.
# 모델 A: 금방 지나갈 거예요 .
#
# Q: 뉴스는 역시 지루해
# 실제 A: 흥미를 가져보세요.
# 모델 A: 뭘 꿨는지 궁금하네요 .
#
# Q: 과거에 얽매여 있어
# 실제 A: 과거랑 현재랑 미래는 함께 해요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 동거하다 사랑이 식으면 어떡해?
# 실제 A: 걱정하면 아무것도 못해요
# 모델 A: 좋은 생각이에요 .
#
# Q: 어떻게 해야 마음을 돌릴 수 있나
# 실제 A: 더 늦지 않게 연락해보세요. 그리고 진심을 전해보세요.
# 모델 A: 뭐든 잘하면 기술이죠 .
#
# Q: 속이 계속 안 좋아
# 실제 A: 신경 쓸 일이 있나봐요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 아 잠수라니
# 실제 A: 상대방에 대한 예의가 없네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 2년사귀다가 헤어젔는데
# 실제 A: 많이 힘들지 않았으면 좋겠네요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나이들수록 좋아하는게 두려워져요.
# 실제 A: 겁이 많아지니까요.
# 모델 A: 마음이 조급해지면 자꾸만 악수를 둘 가능성이 높아집니다 .
#
# Q: 놀고 싶다.
# 실제 A: 저도요!!
# 모델 A: 뭘 먹든 맛있게 드세요 .
#
# Q: 상사한테 또 깨졌어
# 실제 A: 인정 받을 날이 올 거예요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 기다리는게 답일까
# 실제 A: 자신을 사랑하며 기다리세요.
# 모델 A: 사랑은 소유하는 것이 아니에요 .
#
# Q: 음.반복이냐
# 실제 A: 인생은 반복의 연속이지요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 무슨 죄를 지었기에 이렇게 빨리.
# 실제 A: 힘들일이 있었나봐요. 당신의 잘못이 아니에요.
# 모델 A: 좋은 생각이에요 .
#
# Q: 나를 정말 사랑하는 걸까?
# 실제 A: 사랑 받는 자신이 알겠죠.
# 모델 A: 사랑은 알다가도 모르니까요 .
